# %%
from tkinter import *
from tkinter import ttk
import os.path

#from _future_ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = "1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo"
SAMPLE_RANGE_NAME = "Dados!A1:E"
#https://docs.google.com/spreadsheets/d/1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo/edit?usp=sharing

def main():
  """Shows basic usage of the Sheets API.
  Prints values from a sample spreadsheet.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("sheets", "v4", credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = (
        sheet.values()
        .get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range=SAMPLE_RANGE_NAME)
        .execute()
    )

    #Lê os dados da planilha do google sheets
    valores = result.get("values", [])

    display(valores)

    #Criando a janela do Tkinter
    root = Tk()
    root.title('Sistema Google Sheets')

    #Cria uma treeview para exibir os dados da planilha
    tree = ttk.Treeview(root)

    #Define as colunas da Treeview com base nos valores da Linha 1 da planilha
    colunas = valores[0]
    tree["columns"] = colunas

    #for - para
    #Define o cabeçalho da Treeview
    for linha in colunas:
        tree.heading(linha, text=linha)

    #Adiciona os valores da planilha á Treeview
    for row in valores[1:]:
        tree.insert("", "end", values=row)

    #Exibe a Treeview
    tree.pack()

    #Exibo a tela
    root.mainloop()

  except HttpError as err:
      print(err)


if __name__ == "__main__":
  main()
# Out:
# [[],
#  [],
#  ['ID', 'NR. CHAMADO', 'GRUPO SUPORTE', 'RESPONSAVEL', 'FONE'],
#  ['1', 'INC000001463967', 'INFRA_SUP_ORACLE_INCIDENTE'],
#  ['2', 'INC000001194284', 'DWCADASTRO_N2_IBM'],
#  ['3', 'INC000001194285', 'DWCADASTRO_N2_IBM'],
#  ['4', 'INC000001194286', 'DWCADASTRO_N2_IBM'],
#  ['5', 'INC000001194287', 'DWCADASTRO_N2_IBM'],
#  ['6', 'INC000001194288', 'DWCADASTRO_N2_IBM'],
#  ['7', 'INC000001194294', 'DWCADASTRO_N2_IBM'],
#  ['8', 'INC000001196701', 'DWCADASTRO_N2_IBM'],
#  ['9', 'INC000001196702', 'DWCADASTRO_N2_IBM'],
#  ['10', 'INC000001196703', 'DWCADASTRO_N2_IBM'],
#  ['11', 'INC000001196704', 'DWCADASTRO_N2_IBM'],
#  ['12', 'INC000001196705', 'DWCADASTRO_N2_IBM'],
#  ['13', 'INC000001196706', 'DWCADASTRO_N2_IBM'],
#  ['14', 'INC000001196707', 'DWCADASTRO_N2_IBM'],
#  ['15', 'INC000001196722', 'DWCADASTRO_N2_IBM'],
#  ['16', 'INC000001194289', 'DWFINANCEIRO_N2_IBM'],
#  ['17', 'INC000001196719', 'DWFINANCEIRO_N2_IBM'],
#  ['18', 'INC000001196720', 'DWFINANCEIRO_N2_IBM'],
#  ['19', 'INC000001196721', 'DWFINANCEIRO_N2_IBM'],
#  ['20', 'INC000001196104', 'INFORMATICA_N2_OI'],
#  ['21', 'INC000001195627', 'INFRA_SUP_SCHEDULER_OPEN'],
#  ['22', 'INC000001196235', 'INFRA_SUP_SQLSERVER'],
#  ['23', 'INC000001195627', 'INFRA_SUP_UNIX'],
#  ['24', 'INC000001195627', 'PCP_OPEN_N2_OI'],
#  ['25', 'INC000001149602', 'BLL_N2_OI'],
#  ['26', 'INC000001154217', 'CGC_TAHTO'],
#  ['27', 'N/D', 'N/D'],
#  ['28', 'INC000001159535', 'BDO_N2_CLEARTECH'],
#  ['29', 'INC000001165349', 'ACM_N2_OI'],
#  ['30', 'WO0000000459100', 'PCPPRJMARS_N2_3CON'],
#  ['31', 'WO0000000459814', 'PCPPRJMARS_N2_3CON'],
#  ['32', 'INC000001172222', 'CGC_TAHTO'],
#  ['33', 'INC000001172054', 'INFRA_SUP_STORAGE'],
#  ['34', 'N/D', 'N/D'],
#  ['35', 'INC000001171255', 'OI_SUP_APLIC_SIEBEL8'],
#  ['36', 'INC000001171935', 'OI_SUP_APLIC_SIEBEL8'],
#  ['37', 'INC000001171936', 'OI_SUP_APLIC_SIEBEL8'],
#  ['38', 'INC000001171937', 'OI_SUP_APLIC_SIEBEL8'],
#  ['39', 'INC000001172108', 'OI_SUP_APLIC_SIEBEL8'],
#  ['40', 'INC000001171257', 'OI_SUP_APLIC_TVAS'],
#  ['41', 'INC000001172041', 'OMRECURSO_N2_OI'],
#  ['42', 'INC000001175794', 'DWCADASTRO_N2_IBM'],
#  ['43', 'INC000001174697', 'INFRA_SUP_ADABAS_FABRICA'],
#  ['44', 'INC000001176248', 'INFRA_SUP_STORAGE'],
#  ['45', 'INC000001176257', 'INFRA_SUP_STORAGE'],
#  ['46', 'INC000001176701', 'INFRA_SUP_WINDOWS'],
#  ['47', 'N/D', 'N/D'],
#  ['48', 'INC000001176760', 'ARS_N2_OI'],
#  ['49', 'INC000001176667', 'CGC_TAHTO'],
#  ['50', 'INC000001176901', 'INFORMATICA_N2_OI'],
#  ['51', 'INC000001176847', 'INFRA_SUP_ADABAS_FABRICA'],
#  ['52', 'INC000001176902', 'INFRA_SUP_ORACLE_INCIDENTE'],
#  ['53', 'INC000001177044', 'INFRA_SUP_WINDOWS'],
#  ['54', 'INC000001177046', 'INFRA_SUP_WINDOWS'],
#  ['55', 'INC000001177049', 'INFRA_SUP_WINDOWS'],
#  ['56', 'INC000001177050', 'INFRA_SUP_WINDOWS'],
#  ['57', 'INC000001177051', 'INFRA_SUP_WINDOWS'],
#  ['58', 'INC000001177102', 'INFRA_SUP_WINDOWS'],
#  ['59', 'INC000001177104', 'INFRA_SUP_WINDOWS'],
#  ['60', 'INC000001177107', 'INFRA_SUP_WINDOWS'],
#  ['61', 'INC000001176825', 'OI_SUP_APLIC_ARBOR'],
#  ['62', 'INC000001176098', 'OI_SUP_APLIC_TVAS'],
#  ['63', 'INC000001176429', 'OI_SUP_APLIC_TVAS'],
#  ['64', 'INC000001176435', 'OI_SUP_APLIC_TVAS'],
#  ['65', 'INC000001176835', 'OI_SUP_APLIC_TVAS'],
#  ['66', 'INC000001176902', 'OI_SUP_APLIC_TVAS'],
#  ['67', 'INC000001176843', 'RC_N2_WEDO'],
#  ['68', 'INC000001176084', 'SAG_N2_IBM'],
#  ['69', 'INC000001176431', 'SAG_N2_IBM'],
#  ['70', 'INC000001176433', 'SAG_N2_IBM'],
#  ['71', 'INC000001176436', 'SAG_N2_IBM'],
#  ['72', 'INC000001176823', 'SAG_N2_IBM'],
#  ['73', 'INC000001176831', 'SAG_N2_IBM'],
#  ['74', 'INC000001176832', 'SAG_N2_IBM'],
#  ['75', 'INC000001176906', 'SAG_N2_IBM'],
#  ['76', 'INC000001176907', 'SAG_N2_IBM'],
#  ['77', 'INC000001176908', 'SAG_N2_IBM'],
#  ['78', 'INC000001176914', 'SAG_N2_IBM'],
#  ['79', 'INC000001176507', 'SUPORTESIEBEL_N2_OI'],
#  ['80', 'INC000001178491', 'INFORMATICA_N2_OI'],
#  ['81', 'INC000001179613', 'INFRA_SUP_STORAGE'],
#  ['82', 'INC000001178667', 'OI_SUP_APLIC_SIEBEL'],
#  ['83', 'N/D', 'N/D'],
#  ['84', 'INC000001184347', 'COPS_N2_OI'],
#  ['85', 'INC000001184490', 'MONITORACAO_N2_OI'],
#  ['86', 'INC000001190076', 'INFRA_SUP_WINDOWS'],
#  ['87', 'INC000001188961', 'PCPPRJMARS_N2_3CON'],
#  ['88', 'INC000001189724', 'PCPPRJMARS_N2_3CON'],
#  ['89', 'INC000001189908', 'PCPPRJMARS_N2_3CON'],
#  ['90', 'INC000001214474', 'OI_SUP_APLIC_ARBOR'],
#  ['91', 'INC000001214479', 'OI_SUP_APLIC_ARBOR'],
#  ['92', 'INC000001214500', 'OI_SUP_APLIC_ARBOR'],
#  ['93', 'INC000001214932', 'OI_SUP_APLIC_ARBOR'],
#  ['94', 'INC000001214944', 'OI_SUP_APLIC_ARBOR'],
#  ['95', 'INC000001246480', 'CGC_TAHTO'],
#  ['96', 'INC000001245255', 'OI_SUP_APLIC_ARBOR'],
#  ['97', 'INC000001246471', 'OI_SUP_APLIC_ARBOR'],
#  ['98', 'INC000001252113', 'CENTRALIZADOR_N2_IBM'],
#  ['99', 'INC000001265348', 'FIBRABRM_N2_OI'],
#  ['100', 'INC000001264276', 'INFORMATICA_N2_OI'],
#  ['101', 'INC000001264375', 'INFORMATICA_N2_OI'],
#  ['102', 'INC000001264941', 'INFORMATICA_N2_OI'],
#  ['103', 'INC000001266948', 'INFRA_SUP_UNIX'],
#  ['104', 'INC000001266948', 'PCP_OPEN_N2_OI'],
#  ['105', 'INC000001296191', 'ABERTURABA_N1_OI'],
#  ['106', 'INC000001296193', 'CENTRALIZADOR_N2_IBM'],
#  ['107', 'INC000001289144', 'DWMIGMARS_N2_IBM'],
#  ['108', 'INC000001296959', 'OI_FABRICA_ACC_SIEBEL'],
#  ['109', 'INC000001297221', 'OI_FABRICA_ACC_SIEBEL'],
#  ['110', 'INC000001306594', 'PCP_OPEN_N2_OI'],
#  ['111', 'INC000001328276', 'INFRA_SUP_ORACLE_INCIDENTE'],
#  ['112', 'INC000001336998', 'INFRA_SUP_ORACLE_INCIDENTE'],
#  ['113', 'INC000001336998', 'PRODOPEN_CONT_N1_OI'],
#  ['114', 'INC000001338323', 'ITSM_N2_OI'],
#  ['115', 'INC000001342249', 'BDO_N2_CLEARTECH'],
#  ['116', 'CRQ000000035446', 'N/D'],
#  ['117', 'TAS000000185218', 'OI_SUP_APLIC_ROAMBROKER'],
#  ['118', 'INC000001405843', 'INFRA_SUP_UNIX'],
#  ['119', 'INC000001406555', 'N/D'],
#  ['120', 'INC000001446073', 'DWGA_N2_OI'],
#  ['121', 'INC000001446074', 'DWGA_N2_OI'],
#  ['122', 'INC000001446652', 'INFRA_SUP_STORAGE'],
#  ['123', 'INC000001455963', 'DWTRAFEGO_N2_IBM'],
#  ['124', 'INC000001455941', 'INFRA_SUP_SCHEDULER_OPEN'],
#  ['125', 'INC000001456365', 'OI_SUP_APLIC_GEFI'],
#  ['126', 'INC000001464217', 'OI_SUP_APLIC_ARBOR'],
#  ['127', 'INC000001476696', 'OI_SUP_APLIC_GCOB'],
#  ['128', 'INC000001476697', 'OI_SUP_APLIC_GCOB'],
#  ['129', 'INC000001476698', 'OI_SUP_APLIC_GCOB'],
#  ['130', 'INC000001476699', 'OI_SUP_APLIC_GCOB'],
#  ['131', 'INC000001476700', 'OI_SUP_APLIC_GCOB'],
#  ['132', 'INC000001477061', 'OI_SUP_APLIC_GCOB'],
#  ['133', 'INC000001477062', 'OI_SUP_APLIC_GCOB'],
#  ['134', 'INC000001477063', 'OI_SUP_APLIC_GCOB'],
#  ['135', 'INC000001477064', 'OI_SUP_APLIC_GCOB'],
#  ['136', 'INC000001480327', 'INFRA_SUP_MONGODB'],
#  ['137', 'INC000001480330', 'INFRA_SUP_MONGODB'],
#  ['138', 'INC000001483654', 'INFRA_SUP_MONGODB'],
#  ['139', 'INC000001483688', 'INFRA_SUP_MONGODB'],
#  ['140', 'INC000001483263', 'FIBRABRM_N2_OI'],
#  ['141', 'INC000001482985', 'PCP_MAINF_N2_OI'],
#  ['142', 'INC000001483798', 'SUPORTESIEBEL_N2_OI'],
#  ['143', 'INC000001488034', 'OI_SUP_APLIC_SIEBEL'],
#  ['144', 'INC000001489156', 'CLICK_N2_OI'],
#  ['145', 'INC000001488146', 'FIBRABRM_N2_OI'],
#  ['146', 'INC000001488883', 'GEOSITEGEONET_N2_OI'],
#  ['147', 'INC000001488886', 'GEOSITEGEONET_N2_OI'],
#  ['148', 'INC000001488885', 'GEOSITEGEONET_N2_OI'],
#  ['149', 'INC000001488889', 'GEOSITEGEONET_N2_OI'],
#  ['150', 'INC000001488890', 'GEOSITEGEONET_N2_OI'],
#  ['151', 'INC000001488684', 'INTEGRACAO_N2_OI'],
#  ['152', 'INC000001488902', 'SUPORTESIEBEL_N2_OI'],
#  ['153', 'INC000001489103', 'SUPORTESIEBEL_N2_OI'],
#  ['154', 'INC000001489118', 'SUPORTESIEBEL_N2_OI'],
#  ['155', 'INC000001489143', 'SUPORTESIEBEL_N2_OI'],
#  ['156', 'INC000001492178', 'SUPORTESIEBEL_N2_OI'],
#  ['157', 'INC000001493470', 'INFRA_SUP_UNIX'],
#  ['158', 'INC000001493089', 'SUPORTESIEBEL_N2_OI'],
#  ['159', 'INC000001495830', 'DIGITAL_N2_IBM'],
#  ['160', 'INC000001495878', 'DIGITAL_N2_IBM'],
#  ['161', 'INC000001494492', 'FIBRABRM_N2_OI'],
#  ['162', 'INC000001495835', 'GED360_N2_OI'],
#  ['163', 'INC000001496050', 'INFRA_SUP_UNIX'],
#  ['164', 'INC000001496283', 'INFRA_SUP_UNIX'],
#  ['165', 'INC000001496084', 'SUPORTESIEBEL_N2_OI'],
#  ['166', 'INC000001496282', 'SUPORTESIEBEL_N2_OI'],
#  ['167', 'INC000001496305', 'SUPORTESIEBEL_N2_OI'],
#  ['168', 'INC000001500025', 'COBRANCA_N2_OI'],
#  ['169', 'INC000001500153', 'DWCADASTRO_N2_IBM'],
#  ['170', 'INC000001500349', 'FIBRABRM_N2_OI'],
#  ['171', 'INC000001500333', 'FIBRABRM_N2_OI'],
#  ['172', 'INC000001500359', 'FIBRABRM_N2_OI'],
#  ['173', 'INC000001501338', 'IDDIGITAL_N2_OI'],
#  ['174', 'INC000001500262', 'INFORMATICA_N2_OI'],
#  ['175', 'INC000001500519', 'PCP_MAINF_N2_OI'],
#  ['176', 'INC000001500140', 'PCPPRJMARS_N2_3CON'],
#  ['177', 'INC000001500487', 'SUPORTESIEBEL_N2_OI'],
#  ['178', 'INC000001505535', 'CLICK_N2_OI'],
#  ['179', 'INC000001505485', 'COBRANCA_N2_OI'],
#  ['180', 'INC000001505723', 'DWMIGMARS_N2_IBM'],
#  ['181', 'INC000001505735', 'FIBRABRM_N2_OI'],
#  ['182', 'INC000001505468', 'INFORMATICA_N2_OI'],
#  ['183', 'INC000001505733', 'INFORMATICA_N2_OI'],
#  ['184', 'INC000001505734', 'INFORMATICA_N2_OI'],
#  ['185', 'INC000001506503', 'INFRADIGITAL_N2_OI'],
#  ['186', 'INC000001506589', 'INTEGRACAO_N2_OI'],
#  ['187', 'INC000001505190', 'RC_N2_WEDO'],
#  ['188', 'INC000001506304', 'RC_N2_WEDO'],
#  ['189', 'INC000001505861', 'SUPORTESIEBEL_N2_OI'],
#  ['190', 'INC000001509384', 'INFRA_SUP_STORAGE'],
#  ['191', 'INC000001509689', 'SALESFORCE_N2_OI'],
#  ['192', 'INC000001509380', 'SUPORTE_REDE_CORPORATIVA_SP'],
#  ['193', 'INC000001514475', 'INFORMATICA_N2_3CON'],
#  ['194', 'INC000001512979', 'INFORMATICA_N2_OI'],
#  ['195', 'INC000001513455', 'ODS_N2_IBM'],
#  ['196', 'INC000001512579', 'OI_FABRICA_ACC_SIEBEL'],
#  ['197', 'INC000001513702', 'PLATAFORMA_N2_OI'],
#  ['198', 'INC000001513710', 'PLATAFORMA_N2_OI'],
#  ['199', 'INC000001513299', 'PLATAFORMA_N2_OI'],
#  ['200', 'INC000001513732', 'PLATAFORMA_N2_OI'],
#  ['201', 'INC000001513731', 'PLATAFORMA_N2_OI'],
#  ['202', 'INC000001508940', 'PREPAGO_N2_3CON'],
#  ['203', 'INC000001514145', 'RC_N2_WEDO'],
#  ['204', 'INC000001513128', 'SUPORTESIEBEL_N2_OI'],
#  ['205', 'INC000001513724', 'SUPORTESIEBEL_N2_OI'],
#  ['206', 'INC000001513746', 'SUPORTESIEBEL_N2_OI'],
#  ['207', 'INC000001513747', 'SUPORTESIEBEL_N2_OI'],
#  ['208', 'INC000001513763', 'SUPORTESIEBEL_N2_OI'],
#  ['209', 'INC000001513764', 'SUPORTESIEBEL_N2_OI'],
#  ['210', 'INC000001523732', 'INFORMATICA_N2_3CON'],
#  ['211', 'INC000001523734', 'INFORMATICA_N2_3CON'],
#  ['212', 'INC000001523719', 'INFORMATICA_N2_3CON'],
#  ['213', 'INC000001523085', 'INFORMATICA_N2_3CON'],
#  ['214', 'INC000001527378', 'GEOSITEGEONET_N2_OI'],
#  ['215', 'INC000001527379', 'GEOSITEGEONET_N2_OI'],
#  ['216', 'INC000001527383', 'GEOSITEGEONET_N2_OI'],
#  ['217', 'INC000001527505', 'SUPORTESIEBEL_N2_OI'],
#  ['218', 'INC000001530881', 'INFORMATICA_N2_OI'],
#  ['219', 'INC000001531845', 'INFORMATICA_N2_OI'],
#  ['220', 'INC000001532074', 'INFRA_SUP_MYSQL'],
#  ['221', 'INC000001531551', 'SALESFORCE_N2_OI'],
#  ['222', 'INC000001531762', 'SALESFORCE_N2_OI'],
#  ['223', 'INC000001531563', 'SUPORTESIEBEL_N2_OI'],
#  ['224', 'INC000001531567', 'SUPORTESIEBEL_N2_OI'],
#  ['225', 'INC000001537551', 'INFORMATICA_N2_OI'],
#  ['226', 'INC000001536207', 'INFRA_SUP_MYSQL'],
#  ['227', 'INC000001537177', 'INFRA_SUP_WINDOWS'],
#  ['228', 'INC000001537323', 'INTEGRACAO_N2_OI'],
#  ['229', 'INC000001537373', 'PLATAFORMA_N2_OI'],
#  ['230', 'INC000001537374', 'PLATAFORMA_N2_OI'],
#  ['231', 'INC000001537877', 'SALESFORCE_N2_OI'],
#  ['232', 'INC000001541407', 'FIBRABRM_N2_OI'],
#  ['233', 'INC000001540892', 'INFRA_SUP_MONGODB'],
#  ['234', 'INC000001540803', 'INFRA_SUP_UNIX'],
#  ['235', 'INC000001540257', 'OI_SUP_APLIC_ARBOR'],
#  ['236', 'INC000001541004', 'OI_SUP_APLIC_ARBOR'],
#  ['237', 'INC000001541041', 'POWERCURVE_N2_OI'],
#  ['238', 'INC000001540234', 'SISATIVACAOFIXA_N2_OI'],
#  ['239', 'INC000001540085', 'SISATIVACAOFIXA_N2_OI'],
#  ['240', 'INC000001544308', 'INFRA_SUP_WINDOWS'],
#  ['241', 'INC000001544767', 'PLATAFORMA_N2_OI'],
#  ['242', 'INC000001544764', 'PLATAFORMA_N2_OI'],
#  ['243', 'INC000001544786', 'SALESFORCE_N2_OI', 'SYLVIA S DIAS'],
#  ['244', 'INC000001550423', 'POWERCURVE_N2_OI'],
#  ['245', 'INC000001550440', 'POWERCURVE_N2_OI'],
#  ['246', 'INC000001549763', 'SALESFORCE_N2_OI', 'SYLVIA S DIAS'],
#  ['247', 'INC000001549748', 'SALESFORCE_N2_OI', 'SYLVIA S DIAS'],
#  ['248', 'INC000001550977', 'ODS_N2_IBM', 'HOTLINE'],
#  ['249',
#   'INC000001554788',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['250',
#   'INC000001558307',
#   'INFRA_SUP_UNIX',
#   'THIAGO R FRANCO',
#   '31971880020'],
#  ['251',
#   'INC000001558320',
#   'INFRA_SUP_WINDOWS',
#   'EDUARDO D PAIVA',
#   '31991198750'],
#  ['252',
#   'INC000001558307',
#   'OI_SUP_APLIC_ARBOR',
#   'MARCIA S SOUZA',
#   '21988011530'],
#  ['253', 'INC000001558836', 'PLATAFORMA_N2_OI', 'PEDRO H OLIVEIRA'],
#  ['254', 'INC000001558837', 'PLATAFORMA_N2_OI', 'PEDRO H OLIVEIRA'],
#  ['255', 'INC000001558834', 'PLATAFORMA_N2_OI', 'PEDRO H OLIVEIRA'],
#  ['256', 'INC000001558861', 'PLATAFORMA_N2_OI', 'PEDRO H OLIVEIRA'],
#  ['257', 'INC000001558863', 'PLATAFORMA_N2_OI', 'PEDRO H OLIVEIRA'],
#  ['258',
#   'INC000001556198',
#   'SISRAFFAT_N2_IBM',
#   'EDGARD V FERREIRA',
#   '31999517457'],
#  ['259', 'INC000001558551', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['260', 'INC000001556937', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['261', 'INC000001558809', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['262', 'INC000001558834', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['263', 'INC000001558863', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['264', 'INC000001558861', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['265', 'INC000001558862', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['266', 'INC000001558186', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['267', 'INC000001564211', 'INFORMATICA_N2_OI', 'N/D'],
#  ['268',
#   'INC000001569095',
#   'OI_SUP_APLIC_SIEBEL8',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['269', 'INC000001569097', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['270', 'INC000001569302', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['271', 'INC000001569333', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['272', 'INC000001569334', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['273', 'INC000001569342', 'SUPORTESIEBEL_N2_OI', 'WALDOMIRO SILVA'],
#  ['274', 'INC000001570998', 'ODS_N2_IBM', 'PAULO H PINTO', '21996015665'],
#  ['275',
#   'INC000001575463',
#   'GRANITE_N2_OI',
#   'AGUINALDO M NETO',
#   '61993337722'],
#  ['276',
#   'INC000001574470',
#   'INFRA_SUP_WINDOWS',
#   'PLINIO M SANTOS',
#   '11931464732'],
#  ['277', 'INC000001580758', 'FIBRABRM_N2_OI', 'RONALDO A CUNHA'],
#  ['278',
#   'INC000001580505',
#   'INFRA_SUP_WINDOWS',
#   'RENATO F BRAGA',
#   '31987252867'],
#  ['279',
#   'INC000001581355',
#   'SUPORTESIEBEL_N2_OI',
#   'WALDOMIRO SILVA',
#   '61986661674'],
#  ['280', 'INC000001581718', 'ODS_N2_IBM', 'AGNES A PREUSS', '21996015665'],
#  ['281', 'INC000001581724', 'ODS_N2_IBM', 'AGNES A PREUSS', '21996015665'],
#  ['282', 'INC000001581552', 'POWERCURVE_N2_OI'],
#  ['283',
#   'INC000001581356',
#   'SUPORTESIEBEL_N2_OI',
#   'WALDOMIRO SILVA',
#   '61986661674'],
#  ['284',
#   'INC000001581537',
#   'SUPORTESIEBEL_N2_OI',
#   'WALDOMIRO SILVA',
#   '61986661674'],
#  ['285',
#   'INC000001586279',
#   'INFRA_SUP_SQLSERVER',
#   'LEANDRO D PAIXAO',
#   '21985010397'],
#  ['286',
#   'INC000001589077',
#   'PLATAFORMA_N2_OI',
#   'PEDRO H OLIVEIRA',
#   '21959026178'],
#  ['287',
#   'INC000001589083',
#   'PLATAFORMA_N2_OI',
#   'PEDRO H OLIVEIRA',
#   '21959026178'],
#  ['288',
#   'INC000001599976',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['289',
#   'INC000001600522',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['290',
#   'INC000001600100',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371978'],
#  ['291',
#   'INC000001599769',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371979'],
#  ['292',
#   'INC000001599967',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371980'],
#  ['293',
#   'INC000001600505',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371981'],
#  ['294', 'INC000001600115', 'ODS_N2_IBM', 'LUCIANO R SOUZA', '21996015665'],
#  ['295',
#   'INC000001602952',
#   'SISATIVACAOFIXA_N2_OI',
#   'AGUINALDO M NETO',
#   '61993337722'],
#  ['296',
#   'INC000001603514',
#   'INFRA_SUP_UNIX',
#   'THIAGO R FRANCO',
#   '31988642088'],
#  ['297', 'INC000001603706', 'POWERCURVE_N2_OI'],
#  ['298', 'INC000001603709', 'POWERCURVE_N2_OI'],
#  ['299', 'INC000001603710', 'POWERCURVE_N2_OI'],
#  ['300', 'INC000001603711', 'POWERCURVE_N2_OI'],
#  ['301', 'INC000001603712', 'POWERCURVE_N2_OI'],
#  ['302', 'INC000001603718', 'POWERCURVE_N2_OI'],
#  ['303', 'INC000001605673', 'INFORMATICA_N2_3CON'],
#  ['304', 'INC000001605673', 'INFORMATICA_N2_3CON'],
#  ['305',
#   'INC000001606105',
#   'INFRA_SUP_WINDOWS',
#   'RENATO F BRAGA',
#   '31987252867'],
#  ['306', 'INC000001606731', 'FIBRABRM_N2_OI'],
#  ['307', 'INC000001606544', 'FIBRABRM_N2_OI'],
#  ['308', 'INC000001606537', 'INFORMATICA_N2_OI'],
#  ['309',
#   'INC000001613807',
#   'FIBRABRM_N2_OI',
#   'ROGGER S DE PAULA',
#   '21988649152'],
#  ['310', 'INC000001613313', 'INFORMATICA_N2_OI'],
#  ['311',
#   'INC000001613400',
#   'FIBRABRM_N2_OI',
#   'ROGGER S DE PAULA',
#   '21988649152'],
#  ['312',
#   'INC000001614503',
#   'FIBRABRM_N2_OI',
#   'ROGGER S DE PAULA',
#   '21988649153'],
#  ['313',
#   'INC000001613770',
#   'INFRA_SUP_UNIX',
#   'ELBERT S MENDONCA',
#   '21969110479'],
#  ['314', 'INC000001618836', 'FIBRABRM_N2_OI'],
#  ['315', 'INC000001618458', 'FIBRABRM_N2_OI'],
#  ['316', 'INC000001619201'],
#  ['317', '', 'OI_SUP_APLIC_ARBOR'],
#  ['318',
#   'INC000001621304',
#   'OI_SUP_APLIC_SIEBEL8',
#   'WALDOMIRO SILVA',
#   '61986661674'],
#  ['319', 'INC000001621255', 'INFORMATICA_N2_3CON'],
#  ['320',
#   'INC000001624585',
#   'BIGDATAQDS_N2_OI',
#   'ILZA M MENDES',
#   '21988758777'],
#  ['321',
#   'INC000001624585',
#   'BIGDATAQDS_N2_OI',
#   'ILZA M MENDES',
#   '21988758778'],
#  ['322',
#   'INC000001625090',
#   'FIBRABRM_N2_OI',
#   'ROGGER S DE PAULA',
#   '21988649152'],
#  ['323',
#   'INC000001625197',
#   'FIBRABRM_N2_OI',
#   'ROGGER S DE PAULA',
#   '21988649152'],
#  ['324',
#   'INC000001625440',
#   'INFORMATICA_N2_3CON',
#   'JORGE L MESQUITA',
#   '21982371978'],
#  ['325',
#   'INC000001624585',
#   'INFRA_SUP_UNIX',
#   'ELBERT S MENDONCA',
#   '21969110479'],
#  ['326',
#   'INC000001625832',
#   'INFRA_SUP_WINDOWS',
#   'RENATO F BRAGA',
#   '31987252867'],
#  ['327',
#   'INC000001630720',
#   'INFRA_DC_GESTAO_PIEMONTE',
#   'FRANCISCO D FREITAS',
#   '51981370007'],
#  ['328',
#   'INC000001630218',
#   'INFRA_SUP_ORACLE_INCIDENTE',
#   'VITOR C SANCHES',
#   '31988283231'],
#  ['329',
#   'INC000001630942',
#   'INFRA_SUP_UNIX',
#   'EDUARDO M FRAGA',
#   '31988764698'],
#  ['330',
#   'INC000001631402',
#   'INFRA_SUP_UNIX',
#   'ELBERT S MENDONCA',
#   '21969110479'],
#  ['331',
#   'INC000001631734',
#   'INFRA_SUP_UNIX',
#   'ELBERT S MENDONCA',
#   '21969110479'],
#  ['332',
#   'INC000001630489',
#   'OI_SUP_APLIC_ARBOR',
#   'MARCIA S SOUZA',
#   '21988011530'],
#  ['333',
#   'INC000001630240',
#   'OI_SUP_APLIC_SIEBEL8',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['334', 'INC000001631345', 'OI360_N2_ACC', 'SANDRO L MELLO', '81999754607'],
#  ['335',
#   'INC000001631098',
#   'PLATAUT_N2_ACC',
#   'ANDRE L CHRISTINO',
#   '21981232369'],
#  ['336',
#   'INC000001630764',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['337',
#   'INC000001631702',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['338',
#   'INC000001631923',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['339',
#   'INC000001630263',
#   'SFCOMMERCEB2C_N2_OI',
#   'KATIA C FRAGA',
#   '21988010300'],
#  ['340',
#   'INC000001630240',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO DELEON MACEDO',
#   '31988014593'],
#  ['341',
#   'INC000001631135',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['342',
#   'INC000001634377',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['343',
#   'INC000001635823',
#   'REDESIPCORP_N2_OI',
#   'ADRIANO V SILVA',
#   '61986071717'],
#  ['344',
#   'INC000001635823',
#   'SUPORTE_REDE_CORPORATIVA_RJ',
#   'VALNEY BANDEIRA',
#   '41984500807'],
#  ['345',
#   'INC000001635382',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['346',
#   'INC000001635636',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['347',
#   'INC000001638227',
#   'SCB_N2_IBM',
#   'FELIPE DOLABELA LISBOA PINTO',
#   '31997783765'],
#  ['348',
#   'INC000001638604',
#   'INFRA_SUP_ADABAS',
#   'MARCOS H TANIGAKI',
#   '31987665400'],
#  ['349',
#   'INC000001638598',
#   'OI_SUP_APLIC_SIEBEL',
#   'FRANKLIN A SA',
#   '21988740576'],
#  ['350',
#   'INC000001639007',
#   'OI_SUP_APLIC_ARBOR',
#   'ROGGER S PAULA',
#   '21988649152'],
#  ['351',
#   'INC000001638271',
#   'REDESIPCORP_N2_OI',
#   'JOAO C PITTA',
#   '21986642232'],
#  ['352',
#   'INC000001638773',
#   'INFRA_SUP_UNIX',
#   'ELBERT S MENDONCA',
#   '21969110479'],
#  ['353',
#   'INC000001639916',
#   'REDESIPCORP_N2_OI',
#   'JOAO C PITTA',
#   '21986642232'],
#  ['354',
#   'INC000001644405',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['355',
#   'INC000001643831',
#   'ACM_N2_OI',
#   'LEONARDO NETTO D ASSUMPCAO',
#   '21988220240'],
#  ['356',
#   'INC000001644105',
#   'INFRA_SUP_UNIX',
#   'ELBERT S MENDONCA',
#   '21969110479'],
#  ['357',
#   'INC000001644061',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['358',
#   'INC000001644537',
#   'STORAGE_N2_OIINTERNET',
#   'FRANCISCO D ROCHA',
#   '61984264300'],
#  ['359',
#   'INC000001644066',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['360',
#   'INC000001644613',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['361',
#   'INC000001645662',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIR',
#   '21989849113'],
#  ['362',
#   'INC000001645818',
#   'SALESFORCE_N2_OI',
#   'SYLVIA S DIAS',
#   '21988012641'],
#  ['363',
#   'INC000001650123',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['364',
#   'INC000001650040',
#   'INFRA_SUP_BACKUP',
#   'HELOISA H MACHADO',
#   '31987881284'],
#  ['365', 'INC000001648157', 'DIGITAL_N2_OI', 'GABRIEL A SA', '21987948036'],
#  ['366',
#   'INC000001650635',
#   'OPERACAOWEBSUP_N2_OI',
#   'MARCOS C CAETANO',
#   '11969795406'],
#  ['367',
#   'INC000001650040',
#   'INFRA_SUP_BACKUP',
#   'HELOISA H MACHADO',
#   '31987881284'],
#  ['368',
#   'INC000001650905',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['369',
#   'INC000001650919',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['370',
#   'INC000001650372',
#   'PCP_MAINF_N2_OI',
#   'SAMUEL F JALES',
#   '31989202481'],
#  ['371', 'INC000001651008', 'ODS_N2_IBM', 'ALEXANDRE A ALVINO', '21996015665'],
#  ['372', 'INC000001650500', 'ODS_N2_IBM', 'ALEXANDRE A ALVINO', '21996015666'],
#  ['373',
#   'INC000001650857',
#   'FIBRABRM_N2_OI',
#   'DINAQUELE FERREIRA',
#   '21988010097'],
#  ['374',
#   'INC000001651008',
#   'INFRA_SUP_ORACLE_INCIDENTE',
#   'ALMIR R FILHO',
#   '31988976388'],
#  ['375',
#   'INC000001654609',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371978'],
#  ['376', 'INC000001652990', 'FIBRABRM_N2_OI', 'DINAQUELE A FERREIRA'],
#  ['377', 'INC000001652991', 'FIBRABRM_N2_OI', 'DINAQUELE A FERREIRA'],
#  ['378',
#   'INC000001654611',
#   'INFRA_SUP_ORACLE_INCIDENTE',
#   'ALMIR R FILHO',
#   '31988976388'],
#  ['379', 'INC000001654658', 'FIBRABRM_N2_OI', 'DINAQUELE A FERREIRA'],
#  ['380', 'INC000001655313', 'FIBRABRM_N2_OI', 'DINAQUELE A FERREIRA'],
#  ['381', 'INC000001654657', 'FIBRABRM_N2_OI', 'DINAQUELE A FERREIRA'],
#  ['382', 'INC000001655314', 'FIBRABRM_N2_OI', 'DINAQUELE A FERREIRA'],
#  ['383',
#   'INC000001658382',
#   'INFRA_SUP_WINDOWS',
#   'RODRIGO S CUNHA',
#   '51984010270'],
#  ['384',
#   'INC000001659722',
#   'INFRA_SUP_STORAGE',
#   'FRANCISCO D ROCHA',
#   '61984264300'],
#  ['385',
#   'INC000001659934',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['386',
#   'INC000001660137',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['387',
#   'INC000001659968',
#   'INFORMATICA_N2_IBM',
#   'ALEXANDRE A ALVINO',
#   '21996015665'],
#  ['388',
#   'INC000001659969',
#   'INFORMATICA_N2_IBM',
#   'ALEXANDRE A ALVINO',
#   '21996015665'],
#  ['389',
#   'INC000001660631',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['390', 'INC000001660686', 'OPERACAOWEBSUP_N2_OI', 'MARCOS C CAETANO'],
#  ['391', 'INC000001664975', 'ODS_N2_IBM', 'ALEXANDRE A ALVINO', '21996015665'],
#  ['392',
#   'INC000001665926',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['393',
#   'INC000001665936',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['394',
#   'INC000001665949',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['395',
#   'INC000001665694',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['396',
#   'INC000001665696',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['397',
#   'INC000001665957',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['398',
#   'INC000001666195',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['399',
#   'INC000001664031',
#   'REDESIPCORP_N2_OI',
#   'ADRIANO V SILVA',
#   '61986071717'],
#  ['400',
#   'INC000001666509',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['401',
#   'INC000001665596',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['402',
#   'INC000001666422',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['403',
#   'INC000001666265',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['404',
#   'INC000001666266',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['405',
#   'INC000001666267',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['406',
#   'INC000001666089',
#   'FIBRABRM_N2_OI',
#   'ROGGER DA SILVA DE PAULA',
#   '21988649152'],
#  ['407', 'INC000001671521', 'INFRA_SUP_UNIX', 'EDUARDO A ROSA', '41996778549'],
#  ['408', 'INC000001671520', 'INFRA_SUP_UNIX', 'EDUARDO A ROSA', '41996778549'],
#  ['409', 'INC000001722310', 'FIBRABRM_N2_OI', 'RONALDO AGUIAR', '31987832646'],
#  ['410', 'INC000001722309', 'FIBRABRM_N2_OI', 'RONALDO AGUIAR', '31987832647'],
#  ['411',
#   'INC000001726120',
#   'SISTEMAS_ESPEC_N1_OI',
#   'DANIEL F ALVES',
#   '61984731848'],
#  ['412', 'INC000001726546', '', 'ELAINE D XIMENES', '21987635400'],
#  ['413',
#   'INC000001726260',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['414',
#   'INC000001726577',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['415',
#   'INC000001726180',
#   'INFRA_SUP_WINDOWS',
#   'RENATO F BRAGA',
#   '31987252867'],
#  ['416', 'INC000001726518', 'COM_N2_OI', 'RICARDO D PEREIRA', '61984381375'],
#  ['417',
#   'INC000001726694',
#   'SISTEMAS_ESPEC_N1_OI',
#   'DANIEL F ALVES',
#   '61985539696'],
#  ['418',
#   'INC000001727128',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['419',
#   'INC000001729859',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['420',
#   'INC000001729757',
#   'INFRA_SUP_WINDOWS',
#   'DIEGO P MATTOS',
#   '11944643360'],
#  ['421',
#   'INC000001729886',
#   'SISTEMAS_ESPEC_N1_OI',
#   'DANIEL F ALVES',
#   '61985539696'],
#  ['422', 'INC000001730458', 'REDESIPCORP_N2_OI', 'ADRIANO V SILVA'],
#  ['423',
#   'INC000001730427',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['424',
#   'INC000001730825',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['425',
#   'INC000001730925',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['426', 'INC000001730675', '', 'RONALDO A CUNHA'],
#  ['427',
#   'INC000001732489',
#   'OI_FABRICA_ACC_SIEBEL8',
#   'ALISON R FONTES',
#   '21988323551'],
#  ['428',
#   'INC000001732490',
#   'OI_SUP_APLIC_SIEBEL',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['429',
#   'INC000001734011',
#   'OI_SUP_APLIC_SIEBEL',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['430', 'INC000001733879', 'OI360_N2_OI', 'ELAINE B BOLDI', '21988353069'],
#  ['431',
#   'INC000001734401',
#   'OI_SUP_APLIC_SIEBEL',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['432',
#   'INC000001734263',
#   'INFORMATICA_N2_OI',
#   'ALESSANDRO W SANTOS',
#   '21986247926'],
#  ['433',
#   'INC000001736411',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['434',
#   'INC000001735816',
#   'OI_SUP_APLIC_SIEBEL8',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['435',
#   'INC000001736514',
#   'OI_SUP_APLIC_SIEBEL',
#   'JUSTINIANO M SILVA',
#   '21988339968'],
#  ['436',
#   'INC000001734873',
#   'SIEBEL_N3_OI',
#   'FABIO DE SOUZA XAVIER',
#   '21988880020'],
#  ['437',
#   'INC000001736429',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['438',
#   'INC000001735457',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['439',
#   'INC000001736371',
#   'PORTABILIDADE_N2_OI',
#   'ALESSANDRO WERNECK DOS SANTOS',
#   '21986247926'],
#  ['440',
#   'INC000001735834',
#   'PCP_MAINF_N2_OI',
#   'SAMUEL F JALES',
#   '31989202481'],
#  ['441',
#   'INC000001736210',
#   'DIGITAL_N2_IBM',
#   'LIRA B FUKUMOTO',
#   '21999165651'],
#  ['442',
#   'INC000001736210',
#   'INTEGRACAO_N2_OI',
#   'PAULO R GONCALVES',
#   '61984666717'],
#  ['443',
#   'INC000001736701',
#   'GEOSITEGEONET_N2_OI',
#   'AGUINALDO MORAIS NETO',
#   '61985774969'],
#  ['444', 'INC000001736210', 'DIGITAL_N2_OI', 'GABRIEL A SA', '21987948036'],
#  ['445',
#   'INC000001736737',
#   'DIGITAL_N2_IBM',
#   'LIRA B FUKUMOTO',
#   '21999165651'],
#  ['446',
#   'INC000001736737',
#   'MONITORACAO_N2_OI',
#   'GEORGE V MELO',
#   '61984699391'],
#  ['447',
#   'INC000001736498',
#   'MONITORACAO_N2_OI',
#   'GEORGE V MELO',
#   '61984699391'],
#  ['448',
#   'INC000001737089',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['449',
#   'INC000001736947',
#   'FIBRABRM_N2_OI',
#   'DINAQUELE A FERREIRA',
#   '21988010097'],
#  ['450',
#   'INC000001739937',
#   'DIGITAL_N2_IBM',
#   'LIRA B FUKUMOTO',
#   '21999165651'],
#  ['451',
#   'INC000001739836',
#   'SUPORTE_REDE_CORPORATIVA_CE',
#   'VALNEY BANDEIRA',
#   '41984500807'],
#  ['452',
#   'INC000001740226',
#   'INFRA_SUP_MONGODB',
#   'LECIANE A SANTOS',
#   '21980667353'],
#  ['453',
#   'INC000001740236',
#   'REDESIPCORP_N2_OI',
#   'JOAO C PITTA',
#   '21986642232'],
#  ['454', 'INC000001739763', 'CLYFIXA_N2_OI', 'KELLY C PAULA', '31988183140'],
#  ['455',
#   'INC000001739872',
#   'SISTEMAS_ESPEC_N1_OI',
#   'FABIOLA S BRANDAO',
#   '61984731848'],
#  ['456',
#   'INC000001739872',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['457', 'INC000001739399', 'ODS_N2_IBM', 'JOSE C SOUZA', '21996015665'],
#  ['458',
#   'INC000001740831',
#   'INFRA_SUP_WINDOWS',
#   'DIEGO PERGOLI MATTOS',
#   '11944643360'],
#  ['459',
#   'INC000001741060',
#   'INFRA_SUP_ORACLE_SERVICO',
#   'ALMIR R FILHO',
#   '31988976388'],
#  ['460',
#   'INC000001740792',
#   'OI_SUP_APLIC_SIEBEL',
#   'ELEONORA M JUNGER',
#   '21970447788'],
#  ['461',
#   'INC000001743441',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371978'],
#  ['462',
#   'INC000001743351',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371978'],
#  ['463',
#   'INC000001744017',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO DELEON MACEDO',
#   '31988014593'],
#  ['464',
#   'INC000001743835',
#   'GEOSITEGEONET_N2_OI',
#   'AGUINALDO MORAIS NETO',
#   '61993337722'],
#  ['465',
#   'INC000001744093',
#   'INFRA_SUP_SQLSERVER',
#   'RHAGNO J BARROS',
#   '81983735814'],
#  ['466',
#   'INC000001743317',
#   'SAG_N2_IBM',
#   'JOSE CARDOSO VILELA SOUZA',
#   '31989809220'],
#  ['467',
#   'INC000001744507',
#   'FIBRABRM_N2_OI',
#   'DINAQUELE A FERREIRA',
#   '21988010097'],
#  ['468', 'INC000001744605', 'GED360_N2_OI', 'FABIANE MACHADO', '21988012157'],
#  ['469', 'INC000001744533', 'OI360_N2_OI', 'ELAINE B BOLDI', '21988353069'],
#  ['470',
#   'INC000001744397',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['471',
#   'INC000001743803',
#   'INFRA_SUP_UNIX',
#   'THIAGO R FRANCO',
#   '31988642088'],
#  ['472',
#   'INC000001744331',
#   'INFRA_DC_GESTAO_PIEMONTE',
#   'GUILHERME DE OLIVEIRA ROSA',
#   '41992851860'],
#  ['473',
#   'INC000001744328',
#   'INFRA_DC_GESTAO_PIEMONTE',
#   'GUILHERME DE OLIVEIRA ROSA',
#   '41992851860'],
#  ['474',
#   'INC000001744533',
#   'SEGIDDIGITAL_N2_OI',
#   'PATRIK L SANTOS',
#   '61984674124'],
#  ['475',
#   'INC000001745578',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371978'],
#  ['476',
#   'INC000001745579',
#   'INFORMATICA_N2_OI',
#   'JORGE L MESQUITA',
#   '21982371978'],
#  ['477', 'INC000001745383', 'ODS_N2_IBM', 'PAULO E PINHO', '21996015665'],
#  ['478', 'INC000001745094', 'CLICK_N2_OI', 'ARNALDO A ALMEIDA', '61984259873'],
#  ['479', 'INC000001745586', 'CLICK_N2_OI', 'ARNALDO A ALMEIDA', '61984259873'],
#  ['480', 'INC000001745587', 'CLICK_N2_OI', 'ARNALDO A ALMEIDA', '61984259873'],
#  ['481', 'INC000001745095', 'CLICK_N2_OI', 'ARNALDO A ALMEIDA', '61984259873'],
#  ['482', 'INC000001745033', 'INFRA_SUP_STORAGE', 'IVAN J SILVA'],
#  ['483', 'INC000001746141', 'INFRA_SUP_STORAGE', 'IVAN J SILVA'],
#  ['484', 'INC000001746234', 'OI_SUP_APLIC_ARBOR', 'ENVIADO POR EMAIL'],
#  ['485',
#   'INC000001754804',
#   'OI_SUP_APLIC_SIEBEL8',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['486', 'INC000001754809', '', 'BRUNO D PAULA', '21959043727'],
#  ['487', 'INC000001754640', '', 'JOSELAN L FREIRE', '21987220037'],
#  ['488', 'INC000001754642', '', 'JOSELAN L FREIRE', '21987220037'],
#  ['489', 'INC000001754915', '', '', '21996015665'],
#  ['490', 'INC000001754056', '', '', '21982371978'],
#  ['491', 'INC000001755003'],
#  ['492', 'INC000001754670'],
#  ['493', 'INC000001754736'],
#  ['494', 'INC000001754815'],
#  ['495', 'INC000001754692'],
#  ['496', 'INC000001754595'],
#  ['497', 'INC000001754815'],
#  ['498', 'INC000001754938'],
#  ['499', 'INC000001754089'],
#  ['500', 'INC000001754937'],
#  ['501', 'INC000001754859', '', '', '61985774969'],
#  ['502', 'INC000001753996'],
#  ['503', 'INC000001754945'],
#  ['504', 'INC000001755314', '', '', '21986642232'],
#  ['505', 'INC000001755512'],
#  ['506', 'INC000001755552'],
#  ['507', 'INC000001755615'],
#  ['508', 'INC000001755268', 'COBRANCA_N2_OI', 'FILIPE S SILVA', '21988470087'],
#  ['509', 'INC000001758464', '', '', '21989849113'],
#  ['510', 'INC000001758625', '', '', '31988283231'],
#  ['511', 'INC000001758606', '', '', '21987712826'],
#  ['512', 'INC000001758665', '', '', '21987726838'],
#  ['513', 'INC000001760523', '', '', '21988011530'],
#  ['514', 'INC000001759679', '', '', '21988740576'],
#  ['515', 'INC000001760151'],
#  ['516', 'INC000001759691'],
#  ['517', 'INC000001760906', '', '', '21999165651'],
#  ['518', 'INC000001761406'],
#  ['519', 'INC000001761219'],
#  ['520', 'INC000001761272'],
#  ['521', 'INC000001761514'],
#  ['522', 'INC000001761272'],
#  ['523', 'INC000001761514'],
#  ['524', 'INC000001761824'],
#  ['525', 'INC000001762410'],
#  ['526', 'INC000001762016'],
#  ['527', 'INC000001761801'],
#  ['528', 'INC000001764783'],
#  ['529', 'INC000001764680'],
#  ['530', 'INC000001765704'],
#  ['531', 'INC000001765632'],
#  ['532', 'INC000001758870'],
#  ['533', 'INC000001765275'],
#  ['534', 'INC000001765632'],
#  ['535', 'INC000001768339'],
#  ['536', 'INC000001768127'],
#  ['537', 'INC000001768396'],
#  ['538', 'INC000001768397'],
#  ['539', 'INC000001768395'],
#  ['540', 'INC000001768914'],
#  ['541', 'INC000001768320'],
#  ['542', 'INC000001768080'],
#  ['543', 'INC000001769001'],
#  ['544', 'INC000001768231'],
#  ['545', 'INC000001770186'],
#  ['546', 'INC000001769274'],
#  ['547', 'INC000001769277'],
#  ['548', 'INC000001770182'],
#  ['549', 'INC000001770282'],
#  ['550', 'INC000001770618'],
#  ['551', 'INC000001770623'],
#  ['552', 'INC000001770643'],
#  ['553', 'INC000001770055'],
#  ['554', 'INC000001770370'],
#  ['555', 'INC000001770494'],
#  ['556', 'INC000001770719'],
#  ['557', 'INC000001770351'],
#  ['558', 'INC000001770742'],
#  ['559', 'INC000001770742'],
#  ['560', 'INC000001769692'],
#  ['561', 'INC000001770774'],
#  ['562', 'INC000001771009'],
#  ['563', 'INC000001773012'],
#  ['564', 'INC000001772362'],
#  ['565', 'INC000001772652'],
#  ['566', 'INC000001772653'],
#  ['567', 'INC000001772645'],
#  ['568', 'INC000001772652'],
#  ['569', 'INC000001772362'],
#  ['570', 'INC000001772653'],
#  ['571', 'INC000001772978'],
#  ['572', 'INC000001772792'],
#  ['573', 'INC000001772274'],
#  ['574', 'INC000001772299'],
#  ['575', 'INC000001772450'],
#  ['576', 'INC000001772294'],
#  ['577', 'INC000001773311'],
#  ['578', 'INC000001773077'],
#  ['579', 'INC000001772188'],
#  ['580', 'INC000001773363'],
#  ['581', 'INC000001773488'],
#  ['582', 'INC000001773363'],
#  ['583', 'INC000001773664'],
#  ['584', 'INC000001775978'],
#  ['585', 'INC000001776276'],
#  ['586', 'INC000001776284', 'SUPORTESIEBEL_N2_OI', 'ANILTON S OLIVEIRA'],
#  ['587', 'INC000001776439', 'REDESIPCORP_N2_OI', 'VALNEY BANDEIRA '],
#  ['588', 'INC000001776546', 'INFRA_SUP_WINDOWS', 'DIEGO P MATTOS'],
#  ['589', 'INC000001776563', 'SALESFORCE_N2_OI', 'JOSELAN L FREIRE'],
#  ['590', 'INC000001776564', 'SALESFORCE_N2_OI', 'JOSELAN L FREIRE'],
#  ['591', 'INC000001776835', 'SUPORTE_REDE_CORPORATIVA_RJ', 'VALNEY BANDEIRA'],
#  ['592', 'INC000001775578', 'COPS_N2_OI', 'ADRIANA A TOSTA'],
#  ['593', 'INC000001777207', 'FIBRABRM_N2_OI', 'ELAINE D XIMENES'],
#  ['594', 'INC000001777202', 'FIBRABRM_N2_OI', 'ELAINE D XIMENES'],
#  ['595', 'INC000001777017', 'FIBRABRM_N2_OI', 'ELAINE D XIMENES'],
#  ['596', 'INC000001776712', 'FIBRABRM_N2_OI', 'ELAINE D XIMENES'],
#  ['597', 'INC000001777308', 'SUPORTESIEBEL_N2_OI', 'ANILTON S OLIVEIRA'],
#  ['598', 'INC000001777307', 'SUPORTESIEBEL_N2_OI', 'ANILTON S OLIVEIRA'],
#  ['599', 'INC000001777317', 'SUPORTESIEBEL_N2_OI', 'ANILTON S OLIVEIRA'],
#  ['600', 'INC000001777318', 'SUPORTESIEBEL_N2_OI', 'ANILTON S OLIVEIRA'],
#  ['601', 'INC000001777509', 'SALESFORCE_N2_OI', 'JOSELAN L FREIRE'],
#  ['602', 'INC000001779356', 'COBRANCA_N2_OI', 'ADRIANO G COELHO'],
#  ['603', 'INC000001779130', 'OI_SUP_APLIC_SIEBEL8', 'KATIA FRAGA'],
#  ['604', 'INC000001779853', 'OPERACAOWEBSUP_N2_OI', 'MARCOS C CAETANO'],
#  ['605', 'INC000001779447'],
#  ['606', 'INC000001780006'],
#  ['607', 'INC000001780006'],
#  ['608', 'INC000001779940'],
#  ['609', 'INC000001782095'],
#  ['610', 'INC000001781790'],
#  ['611', 'INC000001782250'],
#  ['612', 'INC000001781746'],
#  ['613', 'INC000001782095'],
#  ['614', 'INC000001782505'],
#  ['615', 'INC000001781746'],
#  ['616', 'INC000001782722'],
#  ['617', 'INC000001783016'],
#  ['618', 'INC000001783028'],
#  ['619', 'INC000001783066'],
#  ['620', 'INC000001782650'],
#  ['621', 'INC000001783709'],
#  ['622', 'INC000001786179'],
#  ['623', 'INC000001786180'],
#  ['624', 'INC000001786370'],
#  ['625', 'INC000001786371'],
#  ['626', 'INC000001786372'],
#  ['627', 'INC000001786048'],
#  ['628', 'INC000001785283'],
#  ['629', 'INC000001786432'],
#  ['630', 'INC000001786434'],
#  ['631', 'INC000001786433'],
#  ['632', 'INC000001785888'],
#  ['633', 'INC000001786384'],
#  ['634', 'INC000001785500'],
#  ['635', 'INC000001786903'],
#  ['636', 'INC000001786499'],
#  ['637', 'INC000001786902'],
#  ['638', 'INC000001786467'],
#  ['639', 'INC000001786161'],
#  ['640', 'INC000001786133'],
#  ['641', 'INC000001786741'],
#  ['642', 'INC000001786390'],
#  ['643', 'INC000001786594'],
#  ['644', 'INC000001783995'],
#  ['645', 'INC000001787218'],
#  ['646', 'INC000001789059'],
#  ['647', 'INC000001789528'],
#  ['648', 'INC000001789915'],
#  ['649', 'INC000001789667'],
#  ['650', 'INC000001789667'],
#  ['651', 'INC000001789576', 'FIBRABRM_N2_OI', 'ELAINE D XIMENES'],
#  ['652', 'INC000001789276', 'INFRA_SUP_ORACLE_INCIDENTE', 'VALMIR A OLIVEIRA'],
#  ['653', 'INC000001789477', 'INFRA_SUP_WINDOWS', ' DIEGO P MATTOS'],
#  ['654', 'INC000001789484', 'ASAPMOVEL_N2_OI', 'ALBINO BOMTEMPO'],
#  ['655', 'INC000001790422', 'COM_N2_OI', 'FABIOLA S BRANDAO'],
#  ['656', 'INC000001790265', 'SUPORTESIEBEL_N2_OI', 'LEANDRO D MACEDO'],
#  ['657',
#   'INC000001790292',
#   'SISTEMAS_ESPEC_N1_OI',
#   'FLAVIO M REIS',
#   '61985957380'],
#  ['658', 'INC000001791540', 'OI_SUP_APLIC_SIEBEL', 'RAPHAEL S PEREIRA'],
#  ['659', 'INC000001791194', 'OI_SUP_APLIC_SIEBEL8', 'JOSELAN L FREIRE'],
#  ['660', 'INC000001791534', 'FIBRABRM_N2_OI', 'RONALDO A CUNHA'],
#  ['661', 'INC000001792005', 'INFORMATICA_N2_3CON', 'JORGE L MESQUITA'],
#  ['662', 'INC000001791755', 'INFORMATICA_N2_3CON', 'JORGE L MESQUITA'],
#  ['663', 'INC000001791874', 'SUPORTE_REDE_CORPORATIVA_PR', 'VALNEY BANDEIRA'],
#  ['664', 'INC000001791525', 'SISRAFTAR_N2_IBM', 'JOSE C SOUZA'],
#  ['665', 'INC000001791887', 'SFCOMMERCEB2C_N2_OI', 'ALEXANDRE S DELOGO'],
#  ['666', 'INC000001791553', 'DWCADASTRO_N2_IBM', 'PAULO E PINHO'],
#  ['667', 'INC000001791564', 'DWCADASTRO_N2_IBM', 'PAULO E PINHO'],
#  ['668', 'INC000001791565', 'DWCADASTRO_N2_IBM', 'PAULO E PINHO'],
#  ['669', 'INC000001792009', 'DWCADASTRO_N2_IBM', 'PAULO E PINHO'],
#  ['670', 'INC000001791716', ' BLL_N2_OI', 'RICARDO D PEREIRA'],
#  ['671', 'INC000001791015', ' INFRADIGITAL_N2_OI', 'ELSON E MARTINS'],
#  ['672',
#   'INC000001793768',
#   'OI_SUP_APLIC_SIEBEL',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['673',
#   'INC000001793767',
#   'OI_SUP_APLIC_SIEBEL',
#   'RAPHAEL S PEREIRA',
#   '21986355187'],
#  ['674',
#   'INC000001794159',
#   'OI_SUP_APLIC_ARBOR',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['675',
#   'INC000001793492',
#   'INTEGRACAO_N2_OI',
#   'PAULO R GONCALVES',
#   '61992499925'],
#  ['676',
#   'INC000001794255',
#   'OPERACAOMOBILE_N2_OI',
#   'ARNALDO A ALMEIDA',
#   '61984259873'],
#  ['677',
#   'INC000001794361',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA ',
#   '61984950586'],
#  ['678',
#   'INC000001794856',
#   'INFRA_SUP_UNIX',
#   'THIAGO R FRANCO ',
#   '31971880020'],
#  ['679',
#   'INC000001794864',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['680',
#   'INC000001794862',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['681',
#   'INC000001794863',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['682',
#   'INC000001794872',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['683',
#   'INC000001794856',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA ',
#   '31987832646'],
#  ['684',
#   'INC000001795229',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO ',
#   '61985839563'],
#  ['685',
#   'INC000001795231',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['686',
#   'INC000001795310',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['687',
#   'INC000001795311',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['688',
#   'INC000001794622',
#   'INFRA_SUP_TRANSMISSAO',
#   'AECIO C LACORTE',
#   '31995192292'],
#  ['689',
#   'INC000001795315',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['690',
#   'INC000001795316',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['691',
#   'INC000001795296',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['692',
#   'INC000001795531',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['693',
#   'INC000001795540',
#   'SALESFORCE_N2_OI',
#   'JOSELAN L FREIRE',
#   '21987220037'],
#  ['694',
#   'INC000001798121',
#   'OI_SUP_APLIC_SIEBEL8',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['695', 'INC000001797199', 'FIBRABRM_N2_OI', 'Email', 'Email'],
#  ['696',
#   'INC000001497581',
#   'OI_SUP_APLIC_PORTAL_EMPRESARIAL',
#   'ALEXANDRE R SILVA',
#   '31987580336'],
#  ['697',
#   'INC000001797994',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['698',
#   'INC000001798285',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['699',
#   'INC000001798295',
#   'OI_SUP_APLIC_SIEBEL8',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['700',
#   'INC000001798706',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['701',
#   'INC000001798524',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['702',
#   'INC000001798526',
#   'INFRA_SUP_WINDOWS',
#   'DANIELE C CORREA',
#   '31997999389'],
#  ['703',
#   'INC000001798572',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['704',
#   'INC000001798573',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['705',
#   'INC000001798569',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['706',
#   'INC000001798739',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['707',
#   'INC000001798568',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['708',
#   'INC000001798750',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['709',
#   'INC000001798736',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['710',
#   'INC000001798732',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['711',
#   'INC000001798735',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['712',
#   'INC000001798741',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['713',
#   'INC000001798425',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['714',
#   'INC000001798729',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['715',
#   'INC000001798754',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['716',
#   'INC000001798570',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['717',
#   'INC000001798742',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['718',
#   'INC000001798727',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['719',
#   'INC000001798760',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['720',
#   'INC000001798584',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['721',
#   'INC000001798582',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['722',
#   'INC000001798580',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['723',
#   'INC000001798579',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['724',
#   'INC000001798577',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['725',
#   'INC000001798588',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['726',
#   'INC000001798589',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['727',
#   'INC000001798590',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['728',
#   'INC000001798762',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['729',
#   'INC000001798763',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['730',
#   'INC000001798764',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['731',
#   'INC000001798765',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['732', 'INC000001798766', '', 'ANILTON S OLIVEIRA', '61984950587'],
#  ['733',
#   'INC000001798775',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['734',
#   'INC000001798598',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['735',
#   'INC000001798818',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['736',
#   'INC000001798820',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['737',
#   'INC000001798835',
#   'INFRA_SUP_MYSQL',
#   'LECIANE A SANTOS',
#   '31987582564'],
#  ['738',
#   'INC000001798798',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['739',
#   'INC000001798902',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['740',
#   'INC000001798905',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839564'],
#  ['741',
#   'INC000001798183',
#   'FIBRABRM_N2_OI',
#   'IGOR R VASQUES ',
#   '21989887342'],
#  ['742',
#   'INC000001798930',
#   'OI_SUP_APLIC_SIEBEL8',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['743',
#   'INC000001797661',
#   'INFRA_SUP_WINDOWS',
#   'RODRIGO S CUNHA',
#   '51981128229'],
#  ['744',
#   'INC000001799239',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839564'],
#  ['745',
#   'INC000001797667',
#   'INFRA_SUP_SQLSERVER',
#   'LEANDRO D PAIXAO',
#   '21985010397'],
#  ['746',
#   'INC000001797666',
#   'INFRA_SUP_SQLSERVER',
#   'LEANDRO D PAIXAO',
#   '21985010397'],
#  ['747',
#   'INC000001798996',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839564'],
#  ['748',
#   'INC000001799249',
#   'OI_SUP_APLIC_SIEBEL',
#   'FRANKLIN A SA',
#   '21988740576'],
#  ['749',
#   'INC000001799308',
#   'SISTEMAS_ESPEC_N1_OI',
#   'MARCO A ALVES',
#   '61984273205'],
#  ['750',
#   'INC000001799308',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['751',
#   'INC000001796807',
#   'INFRA_SUP_WINDOWS',
#   'PLINIO M SANTOS',
#   '11931464732'],
#  ['752',
#   'INC000001801842',
#   'INFRA_SUP_MAINFRAME_REDE',
#   'FREDERICO H FERREIRA',
#   '31988969600'],
#  ['753',
#   'INC000001801633',
#   'FIBRABRM_N2_OI',
#   'DINAQUELE A FERREIRA',
#   '21988010097'],
#  ['754',
#   'INC000001801058',
#   'DIGITAL_N2_OI',
#   'MARCOS C CAETANO',
#   '11969795406'],
#  ['755',
#   'INC000001801840',
#   'INTEGRACAO_N2_OI',
#   'PAULO R GONCALVES',
#   '61984666717'],
#  ['756', 'INC000001802003', 'ODS_N2_OI', 'ILZA M MENDES', '21988758777'],
#  ['757',
#   'INC000001802019',
#   'FIBRABRM_N2_OI',
# ...
#  ['822',
#   'INC000001833784',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['823',
#   'INC000001833699',
#   'SUPORTESIEBEL_N2_OI',
#   'LEANDRO D MACEDO',
#   '31988014593'],
#  ['824',
#   'INC000001833982',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['825',
#   'INC000001834029',
#   'OPERACAOWEBSUP_N2_OI',
#   'MARCOS C CAETANO',
#   '11969795406'],
#  ['826',
#   'INC000001834125',
#   'DIGITAL_ESPEC_N1_OI',
#   'ALEXANDRE C LIMA',
#   '21989887778'],
#  ['827',
#   'INC000001834606',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['828',
#   'INC000001834100',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['829',
#   'INC000001834145',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['830',
#   'INC000001834611',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['831',
#   'INC000001834616',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950587'],
#  ['832',
#   'INC000001834679',
#   'SAPBASIS_N2_3CON',
#   'DAWIDSON F ALMEIDA',
#   '31988475867'],
#  ['833',
#   'INC000001834679',
#   'SAPBASIS_N2_3CON',
#   'DAWIDSON F ALMEIDA',
#   '31988475867'],
#  ['834',
#   'INC000001834678',
#   'SAPBASIS_N2_3CON',
#   'DAWIDSON F ALMEIDA',
#   '31988475867'],
#  ['835',
#   'INC000001834681',
#   'INFRA_SUP_STORAGE',
#   'MARCOS A BARBOSA',
#   '61984124081'],
#  ['836',
#   'INC000001834344',
#   'RAIDFMS_N2_OI',
#   'MARCELO D FERREIRA',
#   '21988117425'],
#  ['837',
#   'INC000001834697',
#   'POWERCURVE_N2_OI',
#   'FILIPE S SILVA',
#   '21988470087'],
#  ['838',
#   'INC000001834183',
#   'SISTEMAS_ESPEC_N1_OI',
#   'MARCO A ALVES',
#   '61984273205'],
#  ['839', 'INC000001834800', 'ODS_N2_IBM', 'ISABELLA D SANTOS', '21996015665'],
#  ['840',
#   'INC000001835017',
#   'OI_SUP_APLIC_SIEBEL8',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['841',
#   'INC000001835107',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['842',
#   'INC000001835102',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['843',
#   'INC000001834387',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['844',
#   'INC000001834386',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['845',
#   'INC000001834389',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['846',
#   'INC000001834388',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['847',
#   'INC000001835152',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['848',
#   'INC000001835153',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['849',
#   'INC000001835151',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832647'],
#  ['850',
#   'INC000001837179',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['851',
#   'INC000001837194',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['852', 'INC000001837855', 'ODS_N2_IBM', 'PAULO E PINHO', '21996015665'],
#  ['853',
#   'INC000001837768',
#   'INFRA_SUP_MYSQL',
#   'RHAGNO J BARROS',
#   '81983735814'],
#  ['854',
#   'INC000001838126',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['855',
#   'INC000001841506',
#   'OI_SUP_APLIC_SIEBEL8',
#   'ANTONIO PEREIRA',
#   '21989849113'],
#  ['856',
#   'INC000001841231',
#   'OI_FABRICA_ACC_SIEBEL',
#   'FRANKLIN A SA',
#   '21988740576'],
#  ['857',
#   'INC000001841254',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['858',
#   'INC000001841255',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['859',
#   'INC000001840685',
#   'SALESFORCE_N2_ACC',
#   'ANTONIO PEREIRA',
#   '21989849113'],
#  ['860',
#   'INC000001841231',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ['861',
#   'INC000001841461',
#   'INFRA_SUP_STORAGE',
#   'IVAN J SILVA',
#   '11954102732'],
#  ['862',
#   'INC000001841298',
#   'SALESFORCE_N2_ACC',
#   'ANTONIO PEREIRA',
#   '21989849113'],
#  ['863',
#   'INC000001841562',
#   'RAIDFMS_N2_OI',
#   'MARCELO D FERREIRA',
#   '21988117425'],
#  ['864',
#   'INC000001841360',
#   'FIBRABRM_N2_OI',
#   'TIAGO D RODRIGUES',
#   '21987726838'],
#  ['865', 'INC000001840685', 'SALESFORCE_N2_ACC', 'ANTONIO M PEREIRA', '123'],
#  ['866', 'INC000001840734', 'COM_N2_OI', 'RICARDO D PEREIRA', '61986655727'],
#  ['867', 'INC000001841507', 'FIBRABRM_N2_OI', 'MARCELO HENZE', '21988011630'],
#  ['868',
#   'INC000001841562',
#   'RAIDFMS_N2_OI',
#   'FABIANE MACHADO\t',
#   '21988012157'],
#  ['869',
#   'INC000001842238',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['870',
#   'INC000001841883',
#   'SAPBASIS_N2_3CON',
#   'DAWIDSON F ALMEIDA',
#   '31988475867'],
#  ['871',
#   'INC000001841885',
#   'SAPBASIS_N2_3CON',
#   'DAWIDSON F ALMEIDA',
#   '31988475867'],
#  ['872',
#   'INC000001845333',
#   'OI_SUP_APLIC_SIEBEL8',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['873',
#   'INC000001845332',
#   'OI_SUP_APLIC_SIEBEL',
#   'RAPHAEL S PEREIRA',
#   'INC000001845332'],
#  ['874',
#   'INC000001845300',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['875',
#   'INC000001845652',
#   'SUPORTESIEBEL_N2_OI',
#   'ROGERIO D ARCANJO',
#   '61985839563'],
#  ['876',
#   'INC000001845674',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['877',
#   'INC000001845718',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['878',
#   'INC000001845717',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['879',
#   'INC000001845673',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['880',
#   'INC000001845672',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['881',
#   'INC000001845716',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['882',
#   'INC000001845715',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['883',
#   'INC000001845714',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['884',
#   'INC000001845713',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['885',
#   'INC000001845670',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['886',
#   'INC000001845668',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['887',
#   'INC000001845712',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['888',
#   'INC000001845669',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['889',
#   'INC000001845665',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['890',
#   'INC000001845711',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['891',
#   'INC000001845664',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['892',
#   'INC000001845710',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['893',
#   'INC000001845662',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['894',
#   'INC000001845663',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['895',
#   'INC000001845661',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['896',
#   'INC000001845728',
#   'POWERCURVE_N2_OI',
#   'ADRIANO G COELHO',
#   '21997425403'],
#  ['897',
#   'INC000001845561',
#   'RAIDFMS_N2_OI',
#   'MARCELO D FERREIRA',
#   '21988117425'],
#  ['898',
#   'INC000001845689',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['899',
#   'INC000001845743',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['900',
#   'INC000001845753',
#   'POWERCURVE_N2_OI',
#   'ADRIANO G COELHO',
#   '21997425403'],
#  ['901',
#   'INC000001845753',
#   'POWERCURVE_N2_OI',
#   'FABIANE MACHADO',
#   '21988012157'],
#  ['902',
#   'INC000001846360',
#   'SUPORTE_REDE_CORPORATIVA_PR',
#   'MARCO H SCHENK',
#   '21988012157'],
#  ['903',
#   'INC000001846431',
#   'SUPORTE_REDE_CORPORATIVA_PR',
#   'MARCO H SCHENK',
#   '21988012157'],
#  ['904', 'INC000001849075', 'ODS_N2_IBM', 'RENANN F GONCALVES', '21996015665'],
#  ['905',
#   'INC000001849749',
#   'INFRA_SUP_MYSQL',
#   'RHAGNO J BARROS',
#   '81983735814'],
#  ['906', 'INC000001849458', 'INFRA_SUP_UNIX', 'EDUARDO A ROSA', '21960164752'],
#  ['907',
#   'INC000001851189',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['908',
#   'INC000001851319',
#   'OI_SUP_APLIC_SIEBEL',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['909',
#   'INC000001851263',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['910',
#   'INC000001851193',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['911',
#   'INC000001850982',
#   'INFRA_SUP_ORACLE_INCIDENTE',
#   'MIGUEL A NETO',
#   '31988010845'],
#  ['912',
#   'INC000001851299',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['913',
#   'INC000001839146',
#   'INFRA_SUP_WINDOWS',
#   'RODRIGO S CUNHA',
#   '51981128229'],
#  ['914',
#   'INC000001851478',
#   'SISTEMAS_ESPEC_N1_OI',
#   'DANIEL F ALVES',
#   '61985539696'],
#  ['915',
#   'INC000001848029',
#   'INTEGRACAO_N2_OI',
#   'MATHEUS B SOUZA',
#   '31992000002'],
#  ['916', 'INC000001851720', 'COBRANCA_N2_OI', 'ANA P MARTINS', '21986271967'],
#  ['917',
#   'INC000001851720',
#   'RAIDFMS_N2_OI',
#   'GABRIEL F FERREIRA',
#   '21988000048'],
#  ['918',
#   'INC000001852107',
#   'INFRA_SUP_STORAGE',
#   'IVAN J SILVA',
#   '11954102732'],
#  ['919',
#   'INC000001851600',
#   'FIBRABRM_N2_OI',
#   'RONALDO A CUNHA',
#   '31987832646'],
#  ['920',
#   'INC000001852068',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['921', 'INC000001847965', 'SAP_N2_OI', 'CARLOS S JUNIOR', '21985085160'],
#  ['922', 'INC000001848437', 'SAP_N2_OI', 'CARLOS S JUNIOR', '21985085160'],
#  ['923', 'INC000001848044', 'SAP_N2_OI', 'CARLOS S JUNIOR', '21985085160'],
#  ['924',
#   'INC000001852119',
#   'SALESFORCE_N2_OI',
#   'ANTONIO M PEREIRA',
#   '21989849113'],
#  ['925',
#   'INC000001854763',
#   'RAIDFMS_N2_OI',
#   'MARCELO D FERREIRA',
#   '21988117425'],
#  ['926',
#   'INC000001855053',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['927', 'INC000001854060', 'DIGITAL_N2_OI', 'GABRIEL A SA', '21987948036'],
#  ['928', 'INC000001853991', 'DIGITAL_N2_OI', 'GABRIEL A SA', '21987948036'],
#  ['929',
#   'INC000001853087',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['930',
#   'INC000001853346',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['931',
#   'INC000001853073',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['932',
#   'INC000001855123',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['933',
#   'INC000001855125',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['934',
#   'INC000001855344',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['935',
#   'INC000001855097',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['936',
#   'INC000001854375',
#   'RAIDFMS_N2_OI',
#   'MARCELO D FERREIRA',
#   '21988117425'],
#  ['937',
#   'INC000001855389',
#   'POWERCURVE_N2_OI',
#   'ADRIANO G COELHO',
#   '21987842855'],
#  ['938',
#   'INC000001855458',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['939',
#   'INC000001855053',
#   'POWERCURVE_N2_OI',
#   'ADRIANO G COELHO',
#   '21987842855'],
#  ['940',
#   'INC000001855560',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['941',
#   'INC000001855559',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['942',
#   'INC000001855466',
#   'LEADTOCASH_N2_ACC',
#   'SAMUEL ASCER',
#   '21997675131'],
#  ['943',
#   'INC000001855468',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['944',
#   'INC000001855476',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['945',
#   'INC000001855234',
#   'PCP_MAINF_N2_OI',
#   'RENZO G CARNEIRO',
#   '61984264365'],
#  ['946',
#   'INC000001855478',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['947',
#   'INC000001855739',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['948',
#   'INC000001855906',
#   'POWERCURVE_N2_OI',
#   'ADRIANO G COELHO',
#   '21987842855'],
#  ['949',
#   'INC000001855750',
#   'SALESFORCE_N2_OI',
#   'FELIPE V BARRETO',
#   '21988323551'],
#  ['950',
#   'INC000001855748',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['951',
#   'INC000001855758',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['952',
#   'INC000001855652',
#   'FIBRABRM_N2_OI',
#   'TIAGO D RODRIGUES',
#   '21987726838'],
#  ['953',
#   'INC000001855234',
#   'PCP_MAINF_N2_OI',
#   'RENZO G CARNEIRO',
#   '61984264365'],
#  ['953',
#   'INC000001855931',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['954',
#   'INC000001855776',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['955', 'INC000001858440', 'SVOI_N2_OI', 'AGUINALDO M NETO', '61985774969'],
#  ['956',
#   'INC000001857873',
#   'OI_SUP_APLIC_SIEBEL8',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['957',
#   'INC000001858164',
#   'SISRAFARREC_N2_IBM',
#   'JOAO R MAIA',
#   '31991918159'],
#  ['958',
#   'INC000001858823',
#   'OI_SUP_APLIC_SIEBEL8',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['959',
#   'INC000001858733',
#   'SUPORTE_REDE_CORPORATIVA_SP',
#   'ALESSANDRO T RIOS',
#   '61984032218'],
#  ['960',
#   'INC000001858814',
#   'INFRA_SUP_UNIX',
#   'EDUARDO M FRAGA',
#   '31988764698'],
#  ['961',
#   'INC000001858812',
#   'INFRA_SUP_UNIX',
#   'EDUARDO M FRAGA',
#   '31988764698'],
#  ['962', 'INC000001858873', 'DIGITAL_N2_OI', 'GABRIEL A SA', '21987948036'],
#  ['963',
#   'INC000001853300',
#   'SALESFORCE_N2_OI',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['964',
#   'INC000001859211',
#   'OI_SUP_APLIC_SIEBEL8',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['965',
#   'INC000001859024',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['966',
#   'INC000001859111',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['966',
#   'INC000001859119',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['967',
#   'INC000001859303',
#   'PCP_MAINF_N2_OI',
#   'SAMUEL F JALES',
#   '31989202481'],
#  ['968',
#   'INC000001858954',
#   'DWCADASTRO_N2_IBM',
#   'ISABELLA D SANTOS',
#   '21996015665'],
#  ['969',
#   'INC000001859240',
#   'SALESFORCE_N2_OI',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['970',
#   'INC000001858799',
#   'INFRA_SUP_SQLSERVER',
#   'LECIANE A SANTOS',
#   '21980667353'],
#  ['971',
#   'INC000001859162',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['972',
#   'INC000001859422',
#   'SISTEMAS_ESPEC_N1_OI',
#   'FABIOLA S BRANDAO',
#   '61984731848'],
#  ['973',
#   'INC000001859467',
#   'SISTEMAS_ESPEC_N1_OI',
#   'MARCO A ALVES',
#   '61984273205'],
#  ['974',
#   'INC000001859462',
#   'SUPORTE_REDE_CORPORATIVA_RJ',
#   'ALESSANDRO T RIOS',
#   '61984032218'],
#  ['975',
#   'INC000001859461',
#   'SUPORTE_REDE_CORPORATIVA_RJ',
#   'ALESSANDRO T RIOS',
#   '61984032218'],
#  ['976',
#   'INC000001859435',
#   'INFRA_SUP_ORACLE_SERVICO',
#   'VITOR C SANCHES',
#   '31988283231'],
#  ['977',
#   'INC000001859460',
#   'ASAPMOVEL_N2_OI',
#   'AGUINALDO M NETO',
#   '61993337722'],
#  ['978',
#   'INC000001858793',
#   'INFRA_SUP_WINDOWS',
#   'RENATO F BRAGA',
#   '31987252867'],
#  ['979', 'INC000001861802', 'GED360_N2_OI', 'ANA P MARTINS', '21986271967'],
#  ['980', 'INC000001860898', 'STCDADOS_N2_OI', 'LUIZ O HANRIOT', '31988735237'],
#  ['981',
#   'INC000001861668',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['982',
#   'INC000001861660',
#   'FIBRABRM_N2_OI',
#   'ELAINE D XIMENES',
#   '21987635400'],
#  ['983', 'INC000001861953', 'GED360_N2_OI', 'ANA P MARTINS', '21986271967'],
#  ['984', 'INC000001862175', 'GED360_N2_OI', 'ANA P MARTINS', '21986271967'],
#  ['985',
#   'INC000001860045',
#   'INTEGRACAO_N2_OI',
#   'FERNANDA R MONTEIRO',
#   '61984967420'],
#  ['986',
#   'INC000001862197',
#   'INFRA_SUP_WINDOWS',
#   'EDUARDO D PAIVA',
#   '31991198750'],
#  ['987',
#   'INC000001862306',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['988',
#   'INC000001862351',
#   'ECOMMERCE_N2_OI',
#   'ERICO R MANOEL',
#   '61986471530'],
#  ['989',
#   'INC000001864638',
#   'OI_SUP_APLIC_SIEBEL8',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['990',
#   'INC000001864836',
#   'SALESFORCE_N2_OI',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['991',
#   'INC000001864865',
#   'SALESFORCE_N2_OI',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['992',
#   'INC000001865007',
#   'SALESFORCE_N2_OI',
#   'RAPHAEL S PEREIRA',
#   '21986355186'],
#  ['993',
#   'INC000001865213',
#   'INFRA_SUP_WINDOWS',
#   'RODRIGO S CUNHA',
#   '51984010270'],
#  ['994',
#   'INC000001865019',
#   'INFRA_SUP_WINDOWS',
#   'RODRIGO S CUNHA',
#   '51984010270'],
#  ['995',
#   'INC000001865025',
#   'SUPORTESIEBEL_N2_OI',
#   'ANILTON S OLIVEIRA',
#   '61984950586'],
#  ...]

# %%
from tkinter import *
from tkinter import ttk
import os.path

#from _future_ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = "1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo"
SAMPLE_RANGE_NAME = "Dados!A1:E"
#https://docs.google.com/spreadsheets/d/1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo/edit?usp=sharing

def main():
  """Shows basic usage of the Sheets API.
  Prints values from a sample spreadsheet.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("sheets", "v4", credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = (
        sheet.values()
        .get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range=SAMPLE_RANGE_NAME)
        .execute()
    )

    #Lê os dados da planilha do google sheets
    valores = result.get("values", [])

    #Criando a janela do Tkinter
    root = Tk()
    root.title('Sistema Google Sheets')

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> ESTADO <--
    estado_label = Label(root, text="Estado:", font="Arial 14")
    estado_label.grid(row=0, column=0, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    estados = sorted(list(set(value[0] for value in valores[1:])))

    #Cria a Combobox
    estado_combox = ttk.Combobox(root, values=estados, font="Arial 14")
    estado_combox.grid(row=1, column=0, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> CIDADE <--
    cidade_label = Label(root, text="Cidade:", font="Arial 14")
    cidade_label.grid(row=0, column=1, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    cidades = sorted(list(set(value[1] for value in valores[1:])))

    #Cria a Combobox
    cidade_combox = ttk.Combobox(root, values=cidades, font="Arial 14")
    cidade_combox.grid(row=1, column=1, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> VENDEDOR <--
    vendedor_label = Label(root, text="Vendedor:", font="Arial 14")
    vendedor_label.grid(row=0, column=2, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    vendedores = sorted(list(set(value[2] for value in valores[1:])))

    #Cria a Combobox
    vendedor_combox = ttk.Combobox(root, values=vendedores, font="Arial 14")
    vendedor_combox.grid(row=1, column=2, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> PRODUTO <--
    produto_label = Label(root, text="Produto:", font="Arial 14")
    produto_label.grid(row=0, column=3, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    produtos = sorted(list(set(value[3] for value in valores[1:])))

    #Cria a Combobox
    produto_combox = ttk.Combobox(root, values=produtos, font="Arial 14")
    produto_combox.grid(row=1, column=3, padx=2, pady=2, stick="W")

    #Cria uma treeview para exibir os dados da planilha
    tree = ttk.Treeview(root)

    #Define as colunas da Treeview com base nos valores da Linha 1 da planilha
    colunas = valores[0]
    tree["columns"] = colunas

    #for - para
    #Define o cabeçalho da Treeview
    for linha in colunas:
        tree.heading(linha, text=linha)

    #Adiciona os valores da planilha á Treeview
    for row in valores[1:]:
        tree.insert("", "end", values=row)


    #row - linha
    #column - coluna
    #columnspan - Quantas colunas da tela vai ocupar
    #padx - Espaço entre as Laterais da linha
    #pady - Espaço em cima e embaixo
    #stick - Remove os espaços em branco - NSEW (Norte, Sul Leste e Oeste)
    #grid - Atela dividida em pequena parte como se fosse uma planilha
        
    #Exibe a Treeview
    tree.grid(row=3, column=0, columnspan=6, padx=5, pady=5, stick="NSEW")

    #Exibo a tela
    root.mainloop()

  except HttpError as err:
      print(err)


if __name__ == "__main__":
  main()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 148
#     144       print(err)
#     147 if __name__ == "__main__":
# --> 148   main()
#
# Cell In[2], line 70, in main()
#      67 estado_label.grid(row=0, column=0, padx=2, pady=2, stick="W")
#      69 #Pega as informações da coluna A a partir da segunda linha
# ---> 70 estados = sorted(list(set(value[0] for value in valores[1:])))
#      72 #Cria a Combobox
#      73 estado_combox = ttk.Combobox(root, values=estados, font="Arial 14")
#
# Cell In[2], line 70, in <genexpr>(.0)
#      67 estado_label.grid(row=0, column=0, padx=2, pady=2, stick="W")
#      69 #Pega as informações da coluna A a partir da segunda linha
# ---> 70 estados = sorted(list(set(value[0] for value in valores[1:])))
#      72 #Cria a Combobox
#      73 estado_combox = ttk.Combobox(root, values=estados, font="Arial 14")
#
# IndexError: list index out of range

# %%
from tkinter import *
from tkinter import ttk
import os.path

#from _future_ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = "1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo"
SAMPLE_RANGE_NAME = "Dados1!A1:E"
#https://docs.google.com/spreadsheets/d/1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo/edit?usp=sharing

def main():
  """Shows basic usage of the Sheets API.
  Prints values from a sample spreadsheet.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("sheets", "v4", credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = (
        sheet.values()
        .get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range=SAMPLE_RANGE_NAME)
        .execute()
    )

    #Lê os dados da planilha do google sheets
    valores = result.get("values", [])

    #Criando a janela do Tkinter
    root = Tk()
    root.title('Sistema Google Sheets')

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> ESTADO <--
    estado_label = Label(root, text="Estado:", font="Arial 14")
    estado_label.grid(row=0, column=0, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    estados = sorted(list(set(value[0] for value in valores[1:])))

    #Cria a Combobox
    estado_combox = ttk.Combobox(root, values=estados, font="Arial 14")
    estado_combox.grid(row=1, column=0, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> CIDADE <--
    cidade_label = Label(root, text="Cidade:", font="Arial 14")
    cidade_label.grid(row=0, column=1, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    cidades = sorted(list(set(value[1] for value in valores[1:])))

    #Cria a Combobox
    cidade_combox = ttk.Combobox(root, values=cidades, font="Arial 14")
    cidade_combox.grid(row=1, column=1, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> VENDEDOR <--
    vendedor_label = Label(root, text="Vendedor:", font="Arial 14")
    vendedor_label.grid(row=0, column=2, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    vendedores = sorted(list(set(value[2] for value in valores[1:])))

    #Cria a Combobox
    vendedor_combox = ttk.Combobox(root, values=vendedores, font="Arial 14")
    vendedor_combox.grid(row=1, column=2, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> PRODUTO <--
    produto_label = Label(root, text="Produto:", font="Arial 14")
    produto_label.grid(row=0, column=3, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    produtos = sorted(list(set(value[3] for value in valores[1:])))

    #Cria a Combobox
    produto_combox = ttk.Combobox(root, values=produtos, font="Arial 14")
    produto_combox.grid(row=1, column=3, padx=2, pady=2, stick="W")

    #Cria uma treeview para exibir os dados da planilha
    tree = ttk.Treeview(root)

    #Define as colunas da Treeview com base nos valores da Linha 1 da planilha
    colunas = valores[0]
    tree["columns"] = colunas

    #for - para
    #Define o cabeçalho da Treeview
    for linha in colunas:
        tree.heading(linha, text=linha)

    #Adiciona os valores da planilha á Treeview
    for row in valores[1:]:
        tree.insert("", "end", values=row)


    #row - linha
    #column - coluna
    #columnspan - Quantas colunas da tela vai ocupar
    #padx - Espaço entre as Laterais da linha
    #pady - Espaço em cima e embaixo
    #stick - Remove os espaços em branco - NSEW (Norte, Sul Leste e Oeste)
    #grid - Atela dividida em pequena parte como se fosse uma planilha
        
    #Exibe a Treeview
    tree.grid(row=3, column=0, columnspan=6, padx=5, pady=5, stick="NSEW")

    #Função que filtra os dados
    def filtro():
       
        #Lê as informações da planilha
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()

        #Lê os dados da planilha do google sheets
        valores = result["values"]

        #Opções filtros pega o texto das combobox
        estado = estado_combox.get()
        cidade = cidade_combox.get()
        vendedor = vendedor_combox.get()
        produto = produto_combox.get()

        dados_filtrados = [valores[0]] #Inclui a linha do cabeçalho
        for row in valores[1:]:
           
           if(not estado or row[0] == estado) and \
                (not cidade or row[1] == cidade) and \
                (not vendedor or row[2] == vendedor) and \
                (not produto or row[3] == produto) and \
                (not produto or row[0] == produto):
                dados_filtrados.append(row)

        #Limpa os dados
        for row in tree.get_children():
            tree.delete(row)

        #Atualiza os dados da treeview
        for row in dados_filtrados[1:]:
            tree.insert('', "end", values=row)

    #Cria o botão Filtro
    botao_filtrar = Button(root, text="Filtrar", font="Arial 14", command=filtro)
    botao_filtrar.grid(row=4, column=1, padx=2, pady=2, stick="NSEW")
           
           
       


    #Exibo a tela
    root.mainloop()

  except HttpError as err:
      print(err)


if __name__ == "__main__":
  main()

# %%
from tkinter import *
from tkinter import ttk
import os.path

#from _future_ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = "1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo"
SAMPLE_RANGE_NAME = "Dados1!A1:E"
#https://docs.google.com/spreadsheets/d/1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo/edit?usp=sharing

def main():
  """Shows basic usage of the Sheets API.
  Prints values from a sample spreadsheet.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("sheets", "v4", credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = (
        sheet.values()
        .get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range=SAMPLE_RANGE_NAME)
        .execute()
    )

    #Lê os dados da planilha do google sheets
    valores = result.get("values", [])

    #Criando a janela do Tkinter
    root = Tk()
    root.title('Sistema Google Sheets')

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> ESTADO <--
    estado_label = Label(root, text="Estado:", font="Arial 14")
    estado_label.grid(row=0, column=0, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    estados = sorted(list(set(value[0] for value in valores[1:])))

    #Cria a Combobox
    estado_combobox = ttk.Combobox(root, values=estados, font="Arial 14")
    estado_combobox.grid(row=1, column=0, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> CIDADE <--
    cidade_label = Label(root, text="Cidade:", font="Arial 14")
    cidade_label.grid(row=0, column=1, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    cidades = sorted(list(set(value[1] for value in valores[1:])))

    #Cria a Combobox
    cidade_combobox = ttk.Combobox(root, values=cidades, font="Arial 14")
    cidade_combobox.grid(row=1, column=1, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> VENDEDOR <--
    vendedor_label = Label(root, text="Vendedor:", font="Arial 14")
    vendedor_label.grid(row=0, column=2, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    vendedores = sorted(list(set(value[2] for value in valores[1:])))

    #Cria a Combobox
    vendedor_combobox = ttk.Combobox(root, values=vendedores, font="Arial 14")
    vendedor_combobox.grid(row=1, column=2, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> PRODUTO <--
    produto_label = Label(root, text="Produto:", font="Arial 14")
    produto_label.grid(row=0, column=3, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    produtos = sorted(list(set(value[3] for value in valores[1:])))

    #Cria a Combobox
    produto_combobox = ttk.Combobox(root, values=produtos, font="Arial 14")
    produto_combobox.grid(row=1, column=3, padx=2, pady=2, stick="W")

    #Cria uma treeview para exibir os dados da planilha
    tree = ttk.Treeview(root)

    #Define as colunas da Treeview com base nos valores da Linha 1 da planilha
    colunas = valores[0]
    tree["columns"] = colunas

    #for - para
    #Define o cabeçalho da Treeview
    for linha in colunas:
        tree.heading(linha, text=linha)

    #Adiciona os valores da planilha á Treeview
    for row in valores[1:]:
        tree.insert("", "end", values=row)


    #row - linha
    #column - coluna
    #columnspan - Quantas colunas da tela vai ocupar
    #padx - Espaço entre as Laterais da linha
    #pady - Espaço em cima e embaixo
    #stick - Remove os espaços em branco - NSEW (Norte, Sul Leste e Oeste)
    #grid - Atela dividida em pequena parte como se fosse uma planilha
        
    #Exibe a Treeview
    tree.grid(row=3, column=0, columnspan=6, padx=5, pady=5, stick="NSEW")

    #Função que filtra os dados
    def filtro():
       
        #Lê as informações da planilha
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()

        #Lê os dados da planilha do google sheets
        valores = result["values"]

        #Opções filtros pega o texto das combobox
        estado = estado_combobox.get()
        cidade = cidade_combobox.get()
        vendedor = vendedor_combobox.get()
        produto = produto_combobox.get()

        dados_filtrados = [valores[0]] #Inclui a linha do cabeçalho
        for row in valores[1:]:
           
           if(not estado or row[0] == estado) and \
                (not cidade or row[1] == cidade) and \
                (not vendedor or row[2] == vendedor) and \
                (not produto or row[3] == produto) and \
                (not produto or row[0] == produto):
                dados_filtrados.append(row)

        #Limpa os dados
        for row in tree.get_children():
            tree.delete(row)

        #Atualiza os dados da treeview
        for row in dados_filtrados[1:]:
            tree.insert('', "end", values=row)

    #Cria o botão Filtro
    botao_filtrar = Button(root, text="Filtrar", font="Arial 14", command=filtro)
    botao_filtrar.grid(row=4, column=1, padx=2, pady=2, stick="NSEW")

    def atualiza_cidades(event):
       
       #Obtem o estado selecionado
       estado = estado_combobox.get()

       #Pega as informações da coluna A a partir da segunda linha
       cidades = sorted(list(set([value[1] for value in valores[1:] if value[0] == estado]))) 


       #Polpula a combobox com os valores correspondentes
       cidade_combobox['values'] = cidades


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    estado_combobox.bind("<<ComboboxSelected>>", atualiza_cidades)       
       
    #*************************************************************************************

    def atualiza_vendedores(event):
       
       #Obtem o estado selecionado
       cidade = cidade_combobox.get()

       #Pega as informações da coluna B a partir da segunda linha
       vendedores = sorted(list(set([value[2] for value in valores[1:] if value[1] == cidade]))) 


       #Popula a combobox com os valores correspondentes
       vendedor_combobox['values'] = vendedores


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    cidade_combobox.bind("<<ComboboxSelected>>", atualiza_vendedores)

    #*************************************************************************************

    def atualiza_produtos(event):
       
       #Obtem o estado selecionado
       vendedor = vendedor_combobox.get()

       #Pega as informações da coluna C a partir da segunda linha
       produtos = sorted(list(set([value[3] for value in valores[1:] if value[2] == vendedor]))) 


       #Popula a combobox com os valores correspondentes
       produto_combobox['values'] = produtos


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    vendedor_combobox.bind("<<ComboboxSelected>>", atualiza_produtos)

    #*************************************************************************************

    def chama_filtro_a_cada_mudanca(event):
       
       filtro()

    #Filtro as informações quando selelcionar algo no campo produtos
    produto_combobox.bind("<<ComboboxSelected>>", chama_filtro_a_cada_mudanca)

    #*************************************************************************************

    #Exibo a tela
    root.mainloop()

  except HttpError as err:
      print(err)


if __name__ == "__main__":
  main()

# %%
from tkinter import *
from tkinter import ttk
import os.path

#from _future_ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = "1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo"
SAMPLE_RANGE_NAME = "Dados1!A1:E"
#https://docs.google.com/spreadsheets/d/1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo/edit?usp=sharing

def main():
  """Shows basic usage of the Sheets API.
  Prints values from a sample spreadsheet.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("sheets", "v4", credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = (
        sheet.values()
        .get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range=SAMPLE_RANGE_NAME)
        .execute()
    )

    #Lê os dados da planilha do google sheets
    valores = result.get("values", [])

    #Criando a janela do Tkinter
    root = Tk()
    root.title('Sistema Google Sheets')

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> ESTADO <--
    estado_label = Label(root, text="Estado:", font="Arial 14")
    estado_label.grid(row=0, column=0, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    estados = sorted(list(set(value[0] for value in valores[1:])))

    #Cria a Combobox
    estado_combobox = ttk.Combobox(root, values=estados, font="Arial 14")
    estado_combobox.grid(row=1, column=0, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> CIDADE <--
    cidade_label = Label(root, text="Cidade:", font="Arial 14")
    cidade_label.grid(row=0, column=1, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    cidades = sorted(list(set(value[1] for value in valores[1:])))

    #Cria a Combobox
    cidade_combobox = ttk.Combobox(root, values=cidades, font="Arial 14")
    cidade_combobox.grid(row=1, column=1, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> VENDEDOR <--
    vendedor_label = Label(root, text="Vendedor:", font="Arial 14")
    vendedor_label.grid(row=0, column=2, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    vendedores = sorted(list(set(value[2] for value in valores[1:])))

    #Cria a Combobox
    vendedor_combobox = ttk.Combobox(root, values=vendedores, font="Arial 14")
    vendedor_combobox.grid(row=1, column=2, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> PRODUTO <--
    produto_label = Label(root, text="Produto:", font="Arial 14")
    produto_label.grid(row=0, column=3, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    produtos = sorted(list(set(value[3] for value in valores[1:])))

    #Cria a Combobox
    produto_combobox = ttk.Combobox(root, values=produtos, font="Arial 14")
    produto_combobox.grid(row=1, column=3, padx=2, pady=2, stick="W")

    #Cria uma treeview para exibir os dados da planilha
    tree = ttk.Treeview(root)

    #Define as colunas da Treeview com base nos valores da Linha 1 da planilha
    colunas = valores[0]
    tree["columns"] = colunas

    #for - para
    #Define o cabeçalho da Treeview
    for linha in colunas:
        tree.heading(linha, text=linha)

    #Adiciona os valores da planilha á Treeview
    for row in valores[1:]:
        tree.insert("", "end", values=row)


    #row - linha
    #column - coluna
    #columnspan - Quantas colunas da tela vai ocupar
    #padx - Espaço entre as Laterais da linha
    #pady - Espaço em cima e embaixo
    #stick - Remove os espaços em branco - NSEW (Norte, Sul Leste e Oeste)
    #grid - Atela dividida em pequena parte como se fosse uma planilha
        
    #Exibe a Treeview
    tree.grid(row=3, column=0, columnspan=6, padx=5, pady=5, stick="NSEW")

    #Função que filtra os dados
    def filtro():
       
        #Lê as informações da planilha
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()

        #Lê os dados da planilha do google sheets
        valores = result["values"]

        #Opções filtros pega o texto das combobox
        estado = estado_combobox.get()
        cidade = cidade_combobox.get()
        vendedor = vendedor_combobox.get()
        produto = produto_combobox.get()

        dados_filtrados = [valores[0]] #Inclui a linha do cabeçalho
        for row in valores[1:]:
           
           if(not estado or row[0] == estado) and \
                (not cidade or row[1] == cidade) and \
                (not vendedor or row[2] == vendedor) and \
                (not produto or row[3] == produto) and \
                (not produto or row[0] == produto):
                dados_filtrados.append(row)

        #Limpa os dados
        for row in tree.get_children():
            tree.delete(row)

        #Atualiza os dados da treeview
        for row in dados_filtrados[1:]:
            tree.insert('', "end", values=row)

    #Cria o botão Filtro
    botao_filtrar = Button(root, text="Filtrar", font="Arial 14", command=filtro)
    botao_filtrar.grid(row=4, column=1, padx=2, pady=2, stick="NSEW")

    def atualiza_cidades(event):
       
       #Obtem o estado selecionado
       estado = estado_combobox.get()

       #Pega as informações da coluna A a partir da segunda linha
       cidades = sorted(list(set([value[1] for value in valores[1:] if value[0] == estado]))) 


       #Polpula a combobox com os valores correspondentes
       cidade_combobox['values'] = cidades


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    estado_combobox.bind("<<ComboboxSelected>>", atualiza_cidades)       
       
    #*************************************************************************************

    def atualiza_vendedores(event):
       
       #Obtem o estado selecionado
       cidade = cidade_combobox.get()

       #Pega as informações da coluna B a partir da segunda linha
       vendedores = sorted(list(set([value[2] for value in valores[1:] if value[1] == cidade]))) 


       #Popula a combobox com os valores correspondentes
       vendedor_combobox['values'] = vendedores


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    cidade_combobox.bind("<<ComboboxSelected>>", atualiza_vendedores)

    #*************************************************************************************

    def atualiza_produtos(event):
       
       #Obtem o estado selecionado
       vendedor = vendedor_combobox.get()

       #Pega as informações da coluna C a partir da segunda linha
       produtos = sorted(list(set([value[3] for value in valores[1:] if value[2] == vendedor]))) 


       #Popula a combobox com os valores correspondentes
       produto_combobox['values'] = produtos


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    vendedor_combobox.bind("<<ComboboxSelected>>", atualiza_produtos)

    #*************************************************************************************

    def chama_filtro_a_cada_mudanca(event):
       
       filtro()

    #Filtro as informações quando selelcionar algo no campo produtos
    produto_combobox.bind("<<ComboboxSelected>>", chama_filtro_a_cada_mudanca)

    #*************************************************************************************


    def novo_registro():
       
       #Cria uma janela secundária para cadastrar os dados
       janela_cadastro = Toplevel(root)
       janela_cadastro.title("Cadastrar Produto")

       Label(janela_cadastro, text="Estado:", font="Arial 16").grid(row=0, column=0, padx=2, pady=2)
       estado_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       estado_cadastro.grid(row=0, column=1, padx=2, pady=2)

       Label(janela_cadastro, text="Cidade:", font="Arial 16").grid(row=1, column=0, padx=2, pady=2)
       cidade_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       cidade_cadastro.grid(row=1, column=1, padx=2, pady=2)

       Label(janela_cadastro, text="Vendedor:", font="Arial 16").grid(row=2, column=0, padx=2, pady=2)
       vendedor_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       vendedor_cadastro.grid(row=2, column=1, padx=2, pady=2)

       Label(janela_cadastro, text="Produto:", font="Arial 16").grid(row=3, column=0, padx=2, pady=2)
       produto_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       produto_cadastro.grid(row=3, column=1, padx=2, pady=2)

       
       Label(janela_cadastro, text="Preço:", font="Arial 16").grid(row=4, column=0, padx=2, pady=2)
       preco_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       preco_cadastro.grid(row=4, column=1, padx=2, pady=2)

       #Cria o botão Salvar
       botao_salvar_novo_registro = Button(janela_cadastro, text="Cadastrar", font="Arial 16", command=filtro)
       botao_salvar_novo_registro.grid(row=6, column=0,columnspan=2, padx=2, pady=2, stick="NSEW")

    #Cria o botão Salvar
    botao_novo = Button(root, text="Novo", font="Arial 14", command=novo_registro)
    botao_novo.grid(row=4, column=0, padx=2, pady=2, stick="NSEW")


    #Exibo a tela
    root.mainloop()

  except HttpError as err:
      print(err)


if __name__ == "__main__":
  main()

# %%
from tkinter import *
from tkinter import ttk
import os.path

#from _future_ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = "1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo"
SAMPLE_RANGE_NAME = "Dados1!A1:E"

CREDENTIALS_FILE = 'token.json'
#https://docs.google.com/spreadsheets/d/1-MNPieexz9WJg10vQxHt6wiGfwX4DTJpvkEHR4ZJPGo/edit?usp=sharing

def main():
  """Shows basic usage of the Sheets API.
  Prints values from a sample spreadsheet.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("sheets", "v4", credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = (
        sheet.values()
        .get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range=SAMPLE_RANGE_NAME)
        .execute()
    )

    #Lê os dados da planilha do google sheets
    valores = result.get("values", [])

    #Criando a janela do Tkinter
    root = Tk()
    root.title('Sistema Google Sheets')

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> ESTADO <--
    estado_label = Label(root, text="Estado:", font="Arial 14")
    estado_label.grid(row=0, column=0, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    estados = sorted(list(set(value[0] for value in valores[1:])))

    #Cria a Combobox
    estado_combobox = ttk.Combobox(root, values=estados, font="Arial 14")
    estado_combobox.grid(row=1, column=0, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> CIDADE <--
    cidade_label = Label(root, text="Cidade:", font="Arial 14")
    cidade_label.grid(row=0, column=1, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    cidades = sorted(list(set(value[1] for value in valores[1:])))

    #Cria a Combobox
    cidade_combobox = ttk.Combobox(root, values=cidades, font="Arial 14")
    cidade_combobox.grid(row=1, column=1, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> VENDEDOR <--
    vendedor_label = Label(root, text="Vendedor:", font="Arial 14")
    vendedor_label.grid(row=0, column=2, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    vendedores = sorted(list(set(value[2] for value in valores[1:])))

    #Cria a Combobox
    vendedor_combobox = ttk.Combobox(root, values=vendedores, font="Arial 14")
    vendedor_combobox.grid(row=1, column=2, padx=2, pady=2, stick="W")

    #*************************************************************************************
    #Cria o rótulo para exibir na tela --> PRODUTO <--
    produto_label = Label(root, text="Produto:", font="Arial 14")
    produto_label.grid(row=0, column=3, padx=2, pady=2, stick="W")

    #Pega as informações da coluna A a partir da segunda linha
    produtos = sorted(list(set(value[3] for value in valores[1:])))

    #Cria a Combobox
    produto_combobox = ttk.Combobox(root, values=produtos, font="Arial 14")
    produto_combobox.grid(row=1, column=3, padx=2, pady=2, stick="W")

    #Cria uma treeview para exibir os dados da planilha
    tree = ttk.Treeview(root)

    #Define as colunas da Treeview com base nos valores da Linha 1 da planilha
    colunas = valores[0]
    tree["columns"] = colunas

    #for - para
    #Define o cabeçalho da Treeview
    for linha in colunas:
        tree.heading(linha, text=linha)

    #Adiciona os valores da planilha á Treeview
    for row in valores[1:]:
        tree.insert("", "end", values=row)


    #row - linha
    #column - coluna
    #columnspan - Quantas colunas da tela vai ocupar
    #padx - Espaço entre as Laterais da linha
    #pady - Espaço em cima e embaixo
    #stick - Remove os espaços em branco - NSEW (Norte, Sul Leste e Oeste)
    #grid - Atela dividida em pequena parte como se fosse uma planilha
        
    #Exibe a Treeview
    tree.grid(row=3, column=0, columnspan=6, padx=5, pady=5, stick="NSEW")

    #Função que filtra os dados
    def filtro():
       
        #Lê as informações da planilha
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()

        #Lê os dados da planilha do google sheets
        valores = result["values"]

        #Opções filtros pega o texto das combobox
        estado = estado_combobox.get()
        cidade = cidade_combobox.get()
        vendedor = vendedor_combobox.get()
        produto = produto_combobox.get()

        dados_filtrados = [valores[0]] #Inclui a linha do cabeçalho
        for row in valores[1:]:
           
           if(not estado or row[0] == estado) and \
                (not cidade or row[1] == cidade) and \
                (not vendedor or row[2] == vendedor) and \
                (not produto or row[3] == produto) and \
                (not produto or row[0] == produto):
                dados_filtrados.append(row)

        #Limpa os dados
        for row in tree.get_children():
            tree.delete(row)

        #Atualiza os dados da treeview
        for row in dados_filtrados[1:]:
            tree.insert('', "end", values=row)

    #Cria o botão Filtro
    botao_filtrar = Button(root, text="Filtrar", font="Arial 14", command=filtro)
    botao_filtrar.grid(row=4, column=1, padx=2, pady=2, stick="NSEW")

    def atualiza_cidades(event):
       
       #Obtem o estado selecionado
       estado = estado_combobox.get()

       #Pega as informações da coluna A a partir da segunda linha
       cidades = sorted(list(set([value[1] for value in valores[1:] if value[0] == estado]))) 


       #Polpula a combobox com os valores correspondentes
       cidade_combobox['values'] = cidades


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    estado_combobox.bind("<<ComboboxSelected>>", atualiza_cidades)       
       
    #*************************************************************************************

    def atualiza_vendedores(event):
       
       #Obtem o estado selecionado
       cidade = cidade_combobox.get()

       #Pega as informações da coluna B a partir da segunda linha
       vendedores = sorted(list(set([value[2] for value in valores[1:] if value[1] == cidade]))) 


       #Popula a combobox com os valores correspondentes
       vendedor_combobox['values'] = vendedores


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    cidade_combobox.bind("<<ComboboxSelected>>", atualiza_vendedores)

    #*************************************************************************************

    def atualiza_produtos(event):
       
       #Obtem o estado selecionado
       vendedor = vendedor_combobox.get()

       #Pega as informações da coluna C a partir da segunda linha
       produtos = sorted(list(set([value[3] for value in valores[1:] if value[2] == vendedor]))) 


       #Popula a combobox com os valores correspondentes
       produto_combobox['values'] = produtos


       #Chamo a função para filtrar os dados
       filtro()


    #Adiciona o evento a combobox       
    vendedor_combobox.bind("<<ComboboxSelected>>", atualiza_produtos)

    #*************************************************************************************

    def chama_filtro_a_cada_mudanca(event):
       
       filtro()

    #Filtro as informações quando selelcionar algo no campo produtos
    produto_combobox.bind("<<ComboboxSelected>>", chama_filtro_a_cada_mudanca)

    #*************************************************************************************


    def novo_registro():
       
       #Cria uma janela secundária para cadastrar os dados
       janela_cadastro = Toplevel(root)
       janela_cadastro.title("Cadastrar Produto")

       Label(janela_cadastro, text="Estado:", font="Arial 16").grid(row=0, column=0, padx=2, pady=2)
       estado_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       estado_cadastro.grid(row=0, column=1, padx=2, pady=2)

       Label(janela_cadastro, text="Cidade:", font="Arial 16").grid(row=1, column=0, padx=2, pady=2)
       cidade_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       cidade_cadastro.grid(row=1, column=1, padx=2, pady=2)

       Label(janela_cadastro, text="Vendedor:", font="Arial 16").grid(row=2, column=0, padx=2, pady=2)
       vendedor_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       vendedor_cadastro.grid(row=2, column=1, padx=2, pady=2)

       Label(janela_cadastro, text="Produto:", font="Arial 16").grid(row=3, column=0, padx=2, pady=2)
       produto_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       produto_cadastro.grid(row=3, column=1, padx=2, pady=2)


       Label(janela_cadastro, text="Preço:", font="Arial 16").grid(row=4, column=0, padx=2, pady=2)
       preco_cadastro = Entry(janela_cadastro, font="Arial 16") #Campo de entrada de dados que pega o que o usuário digitar
       preco_cadastro.grid(row=4, column=1, padx=2, pady=2)


        #Obtem os valores dos campos de entrada de dados
       def salvar_dados_google_sheets():
          
          estado = estado_cadastro.get()
          cidade = cidade_cadastro.get()
          vendedor = vendedor_cadastro.get()
          produto = produto_cadastro.get()
          preco = preco_cadastro.get()

          creds = None
          if os.path.exists(CREDENTIALS_FILE): #Verifica se o arquivo de credenciais existe
             creds = Credentials.from_authorized_user_file(CREDENTIALS_FILE, SCOPES) #Carrega as credenciais a partir do arquivo
             
          if not creds or not creds.valid: #Verifica se as credenciais são inválidas ou inexistentes
              if creds and creds.expired and creds.refresh_token: #Verifica se as credenciais expiraram e existe um token de atualização
                 creds.refresh(Request())  #Atualiza as credenciais com o token de atualização  

              else:
                  
                  #Se não houver credenciais ou elas forem inválidas abre o fluxo de autenticação do Google Sheets
                  flow = InstalledAppFlow.from_client_secrets_file(
                        "credentials.json", SCOPES)
                  creds = flow.run_local_server(0) #Executa o fluxo de autenticação

              with open(CREDENTIALS_FILE, 'w') as token: #Abre o arquivo de credenciais para escrita
                 token.write(creds.to_json()) #Escreve as credenciais no arquivo

          # Cria uma instancia da API da planilha do Google Sheets
          service = build("sheets", "v4", credentials=creds) 
          
          values = [[estado, cidade, vendedor, produto, preco]] #Cria uma lista com os valores obtidos dos campos de entrada
          
          body = {'values': values} #Cria um dicionário com a lista de valores

          # Call the Sheets API
          result = service.spreadsheets().values().append(
                             spreadsheetId=SAMPLE_SPREADSHEET_ID, 
                             range=SAMPLE_RANGE_NAME,
                             valueInputOption='USER_ENTERED', insertDataOption='INSERT_ROWS', body=body).execute()
          #Executa o método append para adicionar uma nova linha á planilha Google Sheets

          tree.delete(tree.get_children()) #Remove todas as linhas da 
          result = service.spreadsheet().values().get(
                             spreadsheetId=SAMPLE_SPREADSHEET_ID, 
                             range=SAMPLE_RANGE_NAME).execute() #Executa o método get() para obter os dados da planilha


    


       #Cria o botão Filtro
       botao_salvar_novo_registro = Button(janela_cadastro, text="Cadastrar", font="Arial 16", command=filtro)
       botao_salvar_novo_registro.grid(row=6, column=0,columnspan=2, padx=2, pady=2, stick="NSEW")

    #Cria o botão Salvar
    botao_novo = Button(root, text="Novo", font="Arial 14", command=novo_registro)
    botao_novo.grid(row=4, column=0, padx=2, pady=2, stick="NSEW")


    #Exibo a tela
    root.mainloop()

  except HttpError as err:
      print(err)


if __name__ == "__main__":
  main()
